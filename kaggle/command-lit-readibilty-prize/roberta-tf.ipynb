# %%
#https://www.kaggle.com/tolgadincer/continuous-target-stratification
import re
import os
import numpy as np
import pandas as pd
import random
import math
import tensorflow as tf
import tensorflow_addons as tfa
import logging
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold, StratifiedKFold
from tensorflow.keras import backend as K
from transformers import RobertaTokenizer, TFRobertaModel
from kaggle_datasets import KaggleDatasets
tf.get_logger().setLevel(logging.ERROR)
from kaggle_datasets import KaggleDatasets

# %%
# Configurations
EPOCHS = 100#30#10#70#150
# Batch size
BATCH_SIZE = 16#24
# Seed
SEED = 123
# Learning rate
LR = 2e-5 #0.000040
# Weight decay
WD = LR/EPOCHS
epsilon=1e-6

# Verbosity
VERBOSE = 2
# Number of folds for training
FOLDS = 5
#groups
n_grp=len(pd.read_csv('../input/commonlitreadabilityprize/train.csv'))
path_aug = '../input/data-aug-commonlit-readability-lang-translation/augmented_data.csv'
# Max length
MAX_LEN = 256 #300#250

# Get the trained model we want to use
MODEL = 'roberta-base'

# Let's load our model tokenizer
tokenizer = RobertaTokenizer.from_pretrained(MODEL)

# For tf.dataset
AUTO = tf.data.experimental.AUTOTUNE
# Out:
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
# def create_folds(df, n_s=5, n_grp=None):
#     df['Fold'] = -1
    
#     if n_grp is None:
#         skf = KFold(n_splits=n_s)
#         target = df.target
#     else:
#         skf = StratifiedKFold(n_splits=n_s)
#         df['grp'] = pd.cut(df.target, n_grp, labels=False)
#         target = df.grp
    
#     for fold_no, (t, v) in enumerate(skf.split(target, target)):
#         df.loc[v, 'Fold'] = fold_no
#     return df

# %%
# Function to seed everything
def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    tf.random.set_seed(seed)

# This function tokenize the text according to a transformers model tokenizer
def regular_encode(texts, tokenizer, maxlen = MAX_LEN):
    enc_di = tokenizer.batch_encode_plus(
        texts,
        padding = 'max_length',
        truncation = True,
        max_length = maxlen,
    )
    
    return np.array(enc_di['input_ids'])

# This function encode our training sentences
def encode_texts(x_train, x_val, MAX_LEN):
    x_train = regular_encode(x_train.tolist(), tokenizer, maxlen = MAX_LEN)
    x_val = regular_encode(x_val.tolist(), tokenizer, maxlen = MAX_LEN)
    return x_train, x_val

# Function to transform arrays to tensors
def transform_to_tensors(x_train, x_val, y_train, y_val):
    
    train_dataset = (
        tf.data.Dataset
        .from_tensor_slices((x_train, y_train))
        .repeat()
        .shuffle(2048)
        .batch(BATCH_SIZE)
        .prefetch(AUTO)
    )
    
    valid_dataset = (
        tf.data.Dataset
        .from_tensor_slices((x_val, y_val))
        .batch(BATCH_SIZE)
        .prefetch(AUTO)
    )
    
    return train_dataset, valid_dataset

# Function to build our model
def build_roberta_base_model(max_len = MAX_LEN):
    transformer = TFRobertaModel.from_pretrained(MODEL)
    input_word_ids = tf.keras.layers.Input(shape = (max_len, ), dtype = tf.int32, name = 'input_word_ids')
    sequence_output = transformer(input_word_ids)[0]
    # We only need the cls_token, resulting in a 2d array
    cls_token = sequence_output[:, 0, :]
    output = tf.keras.layers.Dense(1, activation = 'linear', dtype = 'float32')(cls_token)
    model = tf.keras.models.Model(inputs = [input_word_ids], outputs = [output])
    model.compile(#optimizer = tf.keras.optimizers.Adam(lr = LR),#tfa.optimizers.AdamW(learning_rate = LR),#tf.keras.optimizers.Adam(lr = LR),
        optimizer = tfa.optimizers.AdamW(learning_rate = LR, weight_decay=WD, epsilon= epsilon),          
        loss = [tf.keras.losses.MeanSquaredError()],
                  metrics = [tf.keras.metrics.RootMeanSquaredError()])
    return model

# Function to train and evaluate our model
def train_and_evaluate():
    
    # Read our training data
    df = pd.read_csv(path_aug)
    df['target'] = df['final_target']
    df['excerpt'] = df['final_excerpt']
    # Seed everything
    seed_everything(SEED)
    
    # Initiate kfold object with shuffle and a specific seed
#     kfold = KFold(n_splits = FOLDS, shuffle = True, random_state = SEED)
    kfold = StratifiedKFold(n_splits=FOLDS, shuffle = True, random_state = SEED)
    df['grp'] = pd.cut(df.target, n_grp, labels=False)
    target = df.grp
    # Create out of folds array to store predictions
    oof_predictions = np.zeros(len(df))
    
    for fold, (trn_ind, val_ind) in enumerate(kfold.split(df,target)):
        print('\n')
        print('-'*50)
        print(f'Training fold {fold + 1}')
        K.clear_session()
        # Get text features and target
        x_train, x_val = df['excerpt'].iloc[trn_ind], df['excerpt'].iloc[val_ind]
        y_train, y_val = df['target'].iloc[trn_ind].values, df['target'].iloc[val_ind].values
        # Encode our text with Roberta tokenizer
        x_train, x_val = encode_texts(x_train, x_val, MAX_LEN)
        # Function to transform our numpy array to a tf Dataset
        train_dataset, valid_dataset = transform_to_tensors(x_train, x_val, y_train, y_val)
        # Build model
        model = build_roberta_base_model(max_len = MAX_LEN)
        # Model checkpoint
        checkpoint = tf.keras.callbacks.ModelCheckpoint(f'Roberta_Base_{SEED}_{fold + 1}.h5', 
                                                        monitor = 'val_root_mean_squared_error', 
                                                        verbose = VERBOSE, 
                                                        save_best_only = True,
                                                        save_weights_only = True, 
                                                        mode = 'min')
        steps = x_train.shape[0] // (BATCH_SIZE * 16)
        # Training phase
        history = model.fit(train_dataset,
                            batch_size = BATCH_SIZE,
                            epochs = EPOCHS,
                            verbose = VERBOSE,
                            callbacks = [checkpoint],
                            validation_data = valid_dataset,
                            steps_per_epoch = steps)
        
        
        # Load best epoch weights
        model.load_weights(f'Roberta_Base_{SEED}_{fold + 1}.h5')
        # Predict validation set to save them in the out of folds array
        val_pred = model.predict(valid_dataset)
        oof_predictions[val_ind] = val_pred.reshape(-1)
        
    print('\n')
    print('-'*50)
    # Calculate out of folds root mean squared error
    oof_rmse = np.sqrt(mean_squared_error(df['target'], oof_predictions))
    print(f'Our out of folds RMSE is {oof_rmse}')
    

train_and_evaluate()
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:668: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# --------------------------------------------------
# Training fold 1
# Downloading:   0%|          | 0.00/481 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/657M [00:00<?, ?B/s]
# Some layers from the model checkpoint at roberta-base were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at roberta-base.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Epoch 1/100
# 17/17 - 45s - loss: 1.2928 - root_mean_squared_error: 1.1370 - val_loss: 0.8557 - val_root_mean_squared_error: 0.9251
#
# Epoch 00001: val_root_mean_squared_error improved from inf to 0.92506, saving model to Roberta_Base_123_1.h5
# Epoch 2/100
# 17/17 - 21s - loss: 0.7077 - root_mean_squared_error: 0.8412 - val_loss: 0.5356 - val_root_mean_squared_error: 0.7318
#
# Epoch 00002: val_root_mean_squared_error improved from 0.92506 to 0.73182, saving model to Roberta_Base_123_1.h5
# Epoch 3/100
# 17/17 - 21s - loss: 0.7603 - root_mean_squared_error: 0.8719 - val_loss: 0.5667 - val_root_mean_squared_error: 0.7528
#
# Epoch 00003: val_root_mean_squared_error did not improve from 0.73182
# Epoch 4/100
# 17/17 - 21s - loss: 0.4723 - root_mean_squared_error: 0.6872 - val_loss: 0.3697 - val_root_mean_squared_error: 0.6080
#
# Epoch 00004: val_root_mean_squared_error improved from 0.73182 to 0.60800, saving model to Roberta_Base_123_1.h5
# Epoch 5/100
# 17/17 - 21s - loss: 0.7272 - root_mean_squared_error: 0.8528 - val_loss: 0.7854 - val_root_mean_squared_error: 0.8862
#
# Epoch 00005: val_root_mean_squared_error did not improve from 0.60800
# Epoch 6/100
# 17/17 - 21s - loss: 0.6082 - root_mean_squared_error: 0.7799 - val_loss: 0.3856 - val_root_mean_squared_error: 0.6210
#
# Epoch 00006: val_root_mean_squared_error did not improve from 0.60800
# Epoch 7/100
# 17/17 - 21s - loss: 0.4350 - root_mean_squared_error: 0.6596 - val_loss: 0.5502 - val_root_mean_squared_error: 0.7418
#
# Epoch 00007: val_root_mean_squared_error did not improve from 0.60800
# Epoch 8/100
# 17/17 - 22s - loss: 0.3773 - root_mean_squared_error: 0.6143 - val_loss: 0.4275 - val_root_mean_squared_error: 0.6538
#
# Epoch 00008: val_root_mean_squared_error did not improve from 0.60800
# Epoch 9/100
# 17/17 - 21s - loss: 0.3760 - root_mean_squared_error: 0.6132 - val_loss: 0.3391 - val_root_mean_squared_error: 0.5823
#
# Epoch 00009: val_root_mean_squared_error improved from 0.60800 to 0.58231, saving model to Roberta_Base_123_1.h5
# Epoch 10/100
# 17/17 - 21s - loss: 0.3904 - root_mean_squared_error: 0.6248 - val_loss: 0.4753 - val_root_mean_squared_error: 0.6894
#
# Epoch 00010: val_root_mean_squared_error did not improve from 0.58231
# Epoch 11/100
# 17/17 - 21s - loss: 0.4545 - root_mean_squared_error: 0.6742 - val_loss: 0.4242 - val_root_mean_squared_error: 0.6513
#
# Epoch 00011: val_root_mean_squared_error did not improve from 0.58231
# Epoch 12/100
# 17/17 - 21s - loss: 0.3382 - root_mean_squared_error: 0.5816 - val_loss: 0.3035 - val_root_mean_squared_error: 0.5509
#
# Epoch 00012: val_root_mean_squared_error improved from 0.58231 to 0.55092, saving model to Roberta_Base_123_1.h5
# Epoch 13/100
# 17/17 - 21s - loss: 0.3985 - root_mean_squared_error: 0.6313 - val_loss: 0.3452 - val_root_mean_squared_error: 0.5875
#
# Epoch 00013: val_root_mean_squared_error did not improve from 0.55092
# Epoch 14/100
# 17/17 - 21s - loss: 0.3305 - root_mean_squared_error: 0.5749 - val_loss: 0.5672 - val_root_mean_squared_error: 0.7531
#
# Epoch 00014: val_root_mean_squared_error did not improve from 0.55092
# Epoch 15/100
# 17/17 - 21s - loss: 0.3310 - root_mean_squared_error: 0.5753 - val_loss: 0.3519 - val_root_mean_squared_error: 0.5932
#
# Epoch 00015: val_root_mean_squared_error did not improve from 0.55092
# Epoch 16/100
# 17/17 - 21s - loss: 0.3299 - root_mean_squared_error: 0.5743 - val_loss: 0.5913 - val_root_mean_squared_error: 0.7689
#
# Epoch 00016: val_root_mean_squared_error did not improve from 0.55092
# Epoch 17/100
# 17/17 - 21s - loss: 0.3179 - root_mean_squared_error: 0.5638 - val_loss: 0.6235 - val_root_mean_squared_error: 0.7896
#
# Epoch 00017: val_root_mean_squared_error did not improve from 0.55092
# Epoch 18/100
# 17/17 - 21s - loss: 0.3465 - root_mean_squared_error: 0.5886 - val_loss: 0.2948 - val_root_mean_squared_error: 0.5429
#
# Epoch 00018: val_root_mean_squared_error improved from 0.55092 to 0.54291, saving model to Roberta_Base_123_1.h5
# Epoch 19/100
# 17/17 - 21s - loss: 0.2371 - root_mean_squared_error: 0.4869 - val_loss: 0.4988 - val_root_mean_squared_error: 0.7062
#
# Epoch 00019: val_root_mean_squared_error did not improve from 0.54291
# Epoch 20/100
# 17/17 - 21s - loss: 0.3014 - root_mean_squared_error: 0.5490 - val_loss: 0.2734 - val_root_mean_squared_error: 0.5228
#
# Epoch 00020: val_root_mean_squared_error improved from 0.54291 to 0.52283, saving model to Roberta_Base_123_1.h5
# Epoch 21/100
# 17/17 - 21s - loss: 0.3546 - root_mean_squared_error: 0.5955 - val_loss: 0.5772 - val_root_mean_squared_error: 0.7598
#
# Epoch 00021: val_root_mean_squared_error did not improve from 0.52283
# Epoch 22/100
# 17/17 - 21s - loss: 0.2912 - root_mean_squared_error: 0.5396 - val_loss: 0.3447 - val_root_mean_squared_error: 0.5871
#
# Epoch 00022: val_root_mean_squared_error did not improve from 0.52283
# Epoch 23/100
# 17/17 - 21s - loss: 0.3436 - root_mean_squared_error: 0.5862 - val_loss: 0.3273 - val_root_mean_squared_error: 0.5721
#
# Epoch 00023: val_root_mean_squared_error did not improve from 0.52283
# Epoch 24/100
# 17/17 - 21s - loss: 0.3503 - root_mean_squared_error: 0.5918 - val_loss: 0.5053 - val_root_mean_squared_error: 0.7109
#
# Epoch 00024: val_root_mean_squared_error did not improve from 0.52283
# Epoch 25/100
# 17/17 - 21s - loss: 0.3201 - root_mean_squared_error: 0.5658 - val_loss: 0.3008 - val_root_mean_squared_error: 0.5484
#
# Epoch 00025: val_root_mean_squared_error did not improve from 0.52283
# Epoch 26/100
# 17/17 - 21s - loss: 0.2516 - root_mean_squared_error: 0.5016 - val_loss: 0.5753 - val_root_mean_squared_error: 0.7585
#
# Epoch 00026: val_root_mean_squared_error did not improve from 0.52283
# Epoch 27/100
# 17/17 - 21s - loss: 0.2954 - root_mean_squared_error: 0.5436 - val_loss: 0.2696 - val_root_mean_squared_error: 0.5192
#
# Epoch 00027: val_root_mean_squared_error improved from 0.52283 to 0.51920, saving model to Roberta_Base_123_1.h5
# Epoch 28/100
# 17/17 - 21s - loss: 0.2292 - root_mean_squared_error: 0.4788 - val_loss: 0.4299 - val_root_mean_squared_error: 0.6557
#
# Epoch 00028: val_root_mean_squared_error did not improve from 0.51920
# Epoch 29/100
# 17/17 - 21s - loss: 0.2288 - root_mean_squared_error: 0.4784 - val_loss: 0.2705 - val_root_mean_squared_error: 0.5201
#
# Epoch 00029: val_root_mean_squared_error did not improve from 0.51920
# Epoch 30/100
# 17/17 - 21s - loss: 0.2813 - root_mean_squared_error: 0.5304 - val_loss: 0.3663 - val_root_mean_squared_error: 0.6052
#
# Epoch 00030: val_root_mean_squared_error did not improve from 0.51920
# Epoch 31/100
# 17/17 - 21s - loss: 0.2442 - root_mean_squared_error: 0.4942 - val_loss: 0.4492 - val_root_mean_squared_error: 0.6702
#
# Epoch 00031: val_root_mean_squared_error did not improve from 0.51920
# Epoch 32/100
# 17/17 - 21s - loss: 0.2284 - root_mean_squared_error: 0.4779 - val_loss: 0.6120 - val_root_mean_squared_error: 0.7823
#
# Epoch 00032: val_root_mean_squared_error did not improve from 0.51920
# Epoch 33/100
# 17/17 - 21s - loss: 0.2766 - root_mean_squared_error: 0.5260 - val_loss: 0.2267 - val_root_mean_squared_error: 0.4761
#
# Epoch 00033: val_root_mean_squared_error improved from 0.51920 to 0.47609, saving model to Roberta_Base_123_1.h5
# Epoch 34/100
# 17/17 - 21s - loss: 0.2133 - root_mean_squared_error: 0.4619 - val_loss: 0.5256 - val_root_mean_squared_error: 0.7250
#
# Epoch 00034: val_root_mean_squared_error did not improve from 0.47609
# Epoch 35/100
# 17/17 - 21s - loss: 0.2109 - root_mean_squared_error: 0.4593 - val_loss: 0.3041 - val_root_mean_squared_error: 0.5515
#
# Epoch 00035: val_root_mean_squared_error did not improve from 0.47609
# Epoch 36/100
# 17/17 - 21s - loss: 0.2216 - root_mean_squared_error: 0.4707 - val_loss: 0.3858 - val_root_mean_squared_error: 0.6212
#
# Epoch 00036: val_root_mean_squared_error did not improve from 0.47609
# Epoch 37/100
# 17/17 - 21s - loss: 0.1821 - root_mean_squared_error: 0.4268 - val_loss: 0.5252 - val_root_mean_squared_error: 0.7247
#
# Epoch 00037: val_root_mean_squared_error did not improve from 0.47609
# Epoch 38/100
# 17/17 - 21s - loss: 0.1988 - root_mean_squared_error: 0.4459 - val_loss: 0.2760 - val_root_mean_squared_error: 0.5254
#
# Epoch 00038: val_root_mean_squared_error did not improve from 0.47609
# Epoch 39/100
# 17/17 - 21s - loss: 0.1847 - root_mean_squared_error: 0.4297 - val_loss: 0.3107 - val_root_mean_squared_error: 0.5574
#
# Epoch 00039: val_root_mean_squared_error did not improve from 0.47609
# Epoch 40/100
# 17/17 - 21s - loss: 0.2063 - root_mean_squared_error: 0.4542 - val_loss: 0.4993 - val_root_mean_squared_error: 0.7066
#
# Epoch 00040: val_root_mean_squared_error did not improve from 0.47609
# Epoch 41/100
# 17/17 - 21s - loss: 0.1620 - root_mean_squared_error: 0.4025 - val_loss: 0.3503 - val_root_mean_squared_error: 0.5919
#
# Epoch 00041: val_root_mean_squared_error did not improve from 0.47609
# Epoch 42/100
# 17/17 - 21s - loss: 0.1670 - root_mean_squared_error: 0.4087 - val_loss: 0.2670 - val_root_mean_squared_error: 0.5167
#
# Epoch 00042: val_root_mean_squared_error did not improve from 0.47609
# Epoch 43/100
# 17/17 - 21s - loss: 0.1701 - root_mean_squared_error: 0.4124 - val_loss: 0.4750 - val_root_mean_squared_error: 0.6892
#
# Epoch 00043: val_root_mean_squared_error did not improve from 0.47609
# Epoch 44/100
# 17/17 - 21s - loss: 0.1575 - root_mean_squared_error: 0.3969 - val_loss: 0.2898 - val_root_mean_squared_error: 0.5384
#
# Epoch 00044: val_root_mean_squared_error did not improve from 0.47609
# Epoch 45/100
# 17/17 - 21s - loss: 0.1590 - root_mean_squared_error: 0.3988 - val_loss: 0.5647 - val_root_mean_squared_error: 0.7515
#
# Epoch 00045: val_root_mean_squared_error did not improve from 0.47609
# Epoch 46/100
# 17/17 - 21s - loss: 0.2234 - root_mean_squared_error: 0.4727 - val_loss: 0.3115 - val_root_mean_squared_error: 0.5582
#
# Epoch 00046: val_root_mean_squared_error did not improve from 0.47609
# Epoch 47/100
# 17/17 - 21s - loss: 0.1834 - root_mean_squared_error: 0.4283 - val_loss: 0.4195 - val_root_mean_squared_error: 0.6477
#
# Epoch 00047: val_root_mean_squared_error did not improve from 0.47609
# Epoch 48/100
# 17/17 - 21s - loss: 0.1737 - root_mean_squared_error: 0.4168 - val_loss: 0.6188 - val_root_mean_squared_error: 0.7866
#
# Epoch 00048: val_root_mean_squared_error did not improve from 0.47609
# Epoch 49/100
# 17/17 - 21s - loss: 0.1841 - root_mean_squared_error: 0.4291 - val_loss: 0.2611 - val_root_mean_squared_error: 0.5110
#
# Epoch 00049: val_root_mean_squared_error did not improve from 0.47609
# Epoch 50/100
# 17/17 - 21s - loss: 0.1763 - root_mean_squared_error: 0.4199 - val_loss: 0.2874 - val_root_mean_squared_error: 0.5361
#
# Epoch 00050: val_root_mean_squared_error did not improve from 0.47609
# Epoch 51/100
# 17/17 - 21s - loss: 0.1487 - root_mean_squared_error: 0.3856 - val_loss: 0.3206 - val_root_mean_squared_error: 0.5663
#
# Epoch 00051: val_root_mean_squared_error did not improve from 0.47609
# Epoch 52/100
# 17/17 - 21s - loss: 0.1468 - root_mean_squared_error: 0.3832 - val_loss: 0.4355 - val_root_mean_squared_error: 0.6599
#
# Epoch 00052: val_root_mean_squared_error did not improve from 0.47609
# Epoch 53/100
# 17/17 - 22s - loss: 0.1597 - root_mean_squared_error: 0.3996 - val_loss: 0.6858 - val_root_mean_squared_error: 0.8281
#
# Epoch 00053: val_root_mean_squared_error did not improve from 0.47609
# Epoch 54/100
# 17/17 - 21s - loss: 0.1554 - root_mean_squared_error: 0.3941 - val_loss: 0.3349 - val_root_mean_squared_error: 0.5787
#
# Epoch 00054: val_root_mean_squared_error did not improve from 0.47609
# Epoch 55/100
# 17/17 - 21s - loss: 0.1213 - root_mean_squared_error: 0.3483 - val_loss: 0.2392 - val_root_mean_squared_error: 0.4891
#
# Epoch 00055: val_root_mean_squared_error did not improve from 0.47609
# Epoch 56/100
# 17/17 - 21s - loss: 0.1518 - root_mean_squared_error: 0.3897 - val_loss: 0.4334 - val_root_mean_squared_error: 0.6584
#
# Epoch 00056: val_root_mean_squared_error did not improve from 0.47609
# Epoch 57/100
# 17/17 - 21s - loss: 0.1378 - root_mean_squared_error: 0.3712 - val_loss: 0.3031 - val_root_mean_squared_error: 0.5505
#
# Epoch 00057: val_root_mean_squared_error did not improve from 0.47609
# Epoch 58/100
# 17/17 - 21s - loss: 0.1664 - root_mean_squared_error: 0.4079 - val_loss: 0.2047 - val_root_mean_squared_error: 0.4524
#
# Epoch 00058: val_root_mean_squared_error improved from 0.47609 to 0.45243, saving model to Roberta_Base_123_1.h5
# Epoch 59/100
# 17/17 - 21s - loss: 0.1491 - root_mean_squared_error: 0.3861 - val_loss: 0.2055 - val_root_mean_squared_error: 0.4533
#
# Epoch 00059: val_root_mean_squared_error did not improve from 0.45243
# Epoch 60/100
# 17/17 - 21s - loss: 0.1349 - root_mean_squared_error: 0.3673 - val_loss: 0.3006 - val_root_mean_squared_error: 0.5482
#
# Epoch 00060: val_root_mean_squared_error did not improve from 0.45243
# Epoch 61/100
# 17/17 - 21s - loss: 0.1087 - root_mean_squared_error: 0.3296 - val_loss: 0.3569 - val_root_mean_squared_error: 0.5974
#
# Epoch 00061: val_root_mean_squared_error did not improve from 0.45243
# Epoch 62/100
# 17/17 - 21s - loss: 0.0885 - root_mean_squared_error: 0.2976 - val_loss: 0.2982 - val_root_mean_squared_error: 0.5461
#
# Epoch 00062: val_root_mean_squared_error did not improve from 0.45243
# Epoch 63/100
# 17/17 - 21s - loss: 0.1148 - root_mean_squared_error: 0.3388 - val_loss: 0.3364 - val_root_mean_squared_error: 0.5800
#
# Epoch 00063: val_root_mean_squared_error did not improve from 0.45243
# Epoch 64/100
# 17/17 - 21s - loss: 0.0943 - root_mean_squared_error: 0.3071 - val_loss: 0.5162 - val_root_mean_squared_error: 0.7185
#
# Epoch 00064: val_root_mean_squared_error did not improve from 0.45243
# Epoch 65/100
# 17/17 - 21s - loss: 0.0960 - root_mean_squared_error: 0.3099 - val_loss: 0.4456 - val_root_mean_squared_error: 0.6676
#
# Epoch 00065: val_root_mean_squared_error did not improve from 0.45243
# Epoch 66/100
# 17/17 - 21s - loss: 0.1002 - root_mean_squared_error: 0.3165 - val_loss: 0.3259 - val_root_mean_squared_error: 0.5709
#
# Epoch 00066: val_root_mean_squared_error did not improve from 0.45243
# Epoch 67/100
# 17/17 - 21s - loss: 0.1049 - root_mean_squared_error: 0.3239 - val_loss: 0.3145 - val_root_mean_squared_error: 0.5608
#
# Epoch 00067: val_root_mean_squared_error did not improve from 0.45243
# Epoch 68/100
# 17/17 - 21s - loss: 0.1207 - root_mean_squared_error: 0.3474 - val_loss: 0.2234 - val_root_mean_squared_error: 0.4727
#
# Epoch 00068: val_root_mean_squared_error did not improve from 0.45243
# Epoch 69/100
# 17/17 - 21s - loss: 0.0873 - root_mean_squared_error: 0.2955 - val_loss: 0.2741 - val_root_mean_squared_error: 0.5235
#
# Epoch 00069: val_root_mean_squared_error did not improve from 0.45243
# Epoch 70/100
# 17/17 - 21s - loss: 0.0841 - root_mean_squared_error: 0.2899 - val_loss: 0.3643 - val_root_mean_squared_error: 0.6036
#
# Epoch 00070: val_root_mean_squared_error did not improve from 0.45243
# Epoch 71/100
# 17/17 - 21s - loss: 0.1023 - root_mean_squared_error: 0.3198 - val_loss: 0.3126 - val_root_mean_squared_error: 0.5591
#
# Epoch 00071: val_root_mean_squared_error did not improve from 0.45243
# Epoch 72/100
# 17/17 - 21s - loss: 0.1170 - root_mean_squared_error: 0.3421 - val_loss: 0.2576 - val_root_mean_squared_error: 0.5075
#
# Epoch 00072: val_root_mean_squared_error did not improve from 0.45243
# Epoch 73/100
# 17/17 - 21s - loss: 0.0917 - root_mean_squared_error: 0.3029 - val_loss: 0.2180 - val_root_mean_squared_error: 0.4669
#
# Epoch 00073: val_root_mean_squared_error did not improve from 0.45243
# Epoch 74/100
# 17/17 - 21s - loss: 0.1023 - root_mean_squared_error: 0.3199 - val_loss: 0.3113 - val_root_mean_squared_error: 0.5579
#
# Epoch 00074: val_root_mean_squared_error did not improve from 0.45243
# Epoch 75/100
# 17/17 - 21s - loss: 0.1026 - root_mean_squared_error: 0.3203 - val_loss: 0.3615 - val_root_mean_squared_error: 0.6013
#
# Epoch 00075: val_root_mean_squared_error did not improve from 0.45243
# Epoch 76/100
# 17/17 - 21s - loss: 0.0642 - root_mean_squared_error: 0.2534 - val_loss: 0.3549 - val_root_mean_squared_error: 0.5957
#
# Epoch 00076: val_root_mean_squared_error did not improve from 0.45243
# Epoch 77/100
# 17/17 - 21s - loss: 0.0865 - root_mean_squared_error: 0.2941 - val_loss: 0.2697 - val_root_mean_squared_error: 0.5193
#
# Epoch 00077: val_root_mean_squared_error did not improve from 0.45243
# Epoch 78/100
# 17/17 - 21s - loss: 0.0783 - root_mean_squared_error: 0.2798 - val_loss: 0.2093 - val_root_mean_squared_error: 0.4575
#
# Epoch 00078: val_root_mean_squared_error did not improve from 0.45243
# Epoch 79/100
# 17/17 - 21s - loss: 0.0755 - root_mean_squared_error: 0.2747 - val_loss: 0.2047 - val_root_mean_squared_error: 0.4525
#
# Epoch 00079: val_root_mean_squared_error did not improve from 0.45243
# Epoch 80/100
# 17/17 - 21s - loss: 0.0779 - root_mean_squared_error: 0.2790 - val_loss: 0.2044 - val_root_mean_squared_error: 0.4521
#
# Epoch 00080: val_root_mean_squared_error improved from 0.45243 to 0.45210, saving model to Roberta_Base_123_1.h5
# Epoch 81/100
# 17/17 - 21s - loss: 0.0697 - root_mean_squared_error: 0.2641 - val_loss: 0.2403 - val_root_mean_squared_error: 0.4902
#
# Epoch 00081: val_root_mean_squared_error did not improve from 0.45210
# Epoch 82/100
# 17/17 - 21s - loss: 0.0728 - root_mean_squared_error: 0.2699 - val_loss: 0.3594 - val_root_mean_squared_error: 0.5995
#
# Epoch 00082: val_root_mean_squared_error did not improve from 0.45210
# Epoch 83/100
# 17/17 - 21s - loss: 0.0641 - root_mean_squared_error: 0.2533 - val_loss: 0.2333 - val_root_mean_squared_error: 0.4830
#
# Epoch 00083: val_root_mean_squared_error did not improve from 0.45210
# Epoch 84/100
# 17/17 - 21s - loss: 0.0505 - root_mean_squared_error: 0.2247 - val_loss: 0.2985 - val_root_mean_squared_error: 0.5464
#
# Epoch 00084: val_root_mean_squared_error did not improve from 0.45210
# Epoch 85/100
# 17/17 - 21s - loss: 0.0757 - root_mean_squared_error: 0.2751 - val_loss: 0.2259 - val_root_mean_squared_error: 0.4753
#
# Epoch 00085: val_root_mean_squared_error did not improve from 0.45210
# Epoch 86/100
# 17/17 - 21s - loss: 0.0875 - root_mean_squared_error: 0.2957 - val_loss: 0.2653 - val_root_mean_squared_error: 0.5151
#
# Epoch 00086: val_root_mean_squared_error did not improve from 0.45210
# Epoch 87/100
# 17/17 - 21s - loss: 0.0822 - root_mean_squared_error: 0.2866 - val_loss: 0.2443 - val_root_mean_squared_error: 0.4943
#
# Epoch 00087: val_root_mean_squared_error did not improve from 0.45210
# Epoch 88/100
# 17/17 - 21s - loss: 0.0674 - root_mean_squared_error: 0.2597 - val_loss: 0.3707 - val_root_mean_squared_error: 0.6089
#
# Epoch 00088: val_root_mean_squared_error did not improve from 0.45210
# Epoch 89/100
# 17/17 - 21s - loss: 0.0651 - root_mean_squared_error: 0.2552 - val_loss: 0.3333 - val_root_mean_squared_error: 0.5773
#
# Epoch 00089: val_root_mean_squared_error did not improve from 0.45210
# Epoch 90/100
# 17/17 - 21s - loss: 0.0623 - root_mean_squared_error: 0.2496 - val_loss: 0.3236 - val_root_mean_squared_error: 0.5689
#
# Epoch 00090: val_root_mean_squared_error did not improve from 0.45210
# Epoch 91/100
# 17/17 - 21s - loss: 0.0682 - root_mean_squared_error: 0.2612 - val_loss: 0.2525 - val_root_mean_squared_error: 0.5025
#
# Epoch 00091: val_root_mean_squared_error did not improve from 0.45210
# Epoch 92/100
# 17/17 - 21s - loss: 0.0591 - root_mean_squared_error: 0.2431 - val_loss: 0.2422 - val_root_mean_squared_error: 0.4921
#
# Epoch 00092: val_root_mean_squared_error did not improve from 0.45210
# Epoch 93/100
# 17/17 - 21s - loss: 0.0710 - root_mean_squared_error: 0.2665 - val_loss: 0.3602 - val_root_mean_squared_error: 0.6002
#
# Epoch 00093: val_root_mean_squared_error did not improve from 0.45210
# Epoch 94/100
# 17/17 - 21s - loss: 0.0682 - root_mean_squared_error: 0.2611 - val_loss: 0.4663 - val_root_mean_squared_error: 0.6829
#
# Epoch 00094: val_root_mean_squared_error did not improve from 0.45210
# Epoch 95/100
# 17/17 - 21s - loss: 0.0641 - root_mean_squared_error: 0.2531 - val_loss: 0.2485 - val_root_mean_squared_error: 0.4985
#
# Epoch 00095: val_root_mean_squared_error did not improve from 0.45210
# Epoch 96/100
# 17/17 - 21s - loss: 0.0572 - root_mean_squared_error: 0.2392 - val_loss: 0.2533 - val_root_mean_squared_error: 0.5033
#
# Epoch 00096: val_root_mean_squared_error did not improve from 0.45210
# Epoch 97/100
# 17/17 - 21s - loss: 0.0596 - root_mean_squared_error: 0.2442 - val_loss: 0.3207 - val_root_mean_squared_error: 0.5663
#
# Epoch 00097: val_root_mean_squared_error did not improve from 0.45210
# Epoch 98/100
# 17/17 - 21s - loss: 0.0564 - root_mean_squared_error: 0.2375 - val_loss: 0.3627 - val_root_mean_squared_error: 0.6023
#
# Epoch 00098: val_root_mean_squared_error did not improve from 0.45210
# Epoch 99/100
# 17/17 - 21s - loss: 0.0633 - root_mean_squared_error: 0.2516 - val_loss: 0.3433 - val_root_mean_squared_error: 0.5859
#
# Epoch 00099: val_root_mean_squared_error did not improve from 0.45210
# Epoch 100/100
# 17/17 - 21s - loss: 0.0528 - root_mean_squared_error: 0.2299 - val_loss: 0.3412 - val_root_mean_squared_error: 0.5841
#
# Epoch 00100: val_root_mean_squared_error did not improve from 0.45210
#
#
# --------------------------------------------------
# Training fold 2
# Some layers from the model checkpoint at roberta-base were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at roberta-base.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Epoch 1/100
# 17/17 - 43s - loss: 1.2024 - root_mean_squared_error: 1.0966 - val_loss: 0.9997 - val_root_mean_squared_error: 0.9998
#
# Epoch 00001: val_root_mean_squared_error improved from inf to 0.99984, saving model to Roberta_Base_123_2.h5
# Epoch 2/100
# 17/17 - 21s - loss: 0.9272 - root_mean_squared_error: 0.9629 - val_loss: 0.5483 - val_root_mean_squared_error: 0.7405
#
# Epoch 00002: val_root_mean_squared_error improved from 0.99984 to 0.74051, saving model to Roberta_Base_123_2.h5
# Epoch 3/100
# 17/17 - 21s - loss: 0.5725 - root_mean_squared_error: 0.7567 - val_loss: 0.5671 - val_root_mean_squared_error: 0.7531
#
# Epoch 00003: val_root_mean_squared_error did not improve from 0.74051
# Epoch 4/100
# 17/17 - 21s - loss: 0.4987 - root_mean_squared_error: 0.7062 - val_loss: 0.4256 - val_root_mean_squared_error: 0.6524
#
# Epoch 00004: val_root_mean_squared_error improved from 0.74051 to 0.65240, saving model to Roberta_Base_123_2.h5
# Epoch 5/100
# 17/17 - 21s - loss: 0.4967 - root_mean_squared_error: 0.7048 - val_loss: 0.3815 - val_root_mean_squared_error: 0.6177
#
# Epoch 00005: val_root_mean_squared_error improved from 0.65240 to 0.61766, saving model to Roberta_Base_123_2.h5
# Epoch 6/100
# 17/17 - 21s - loss: 0.5293 - root_mean_squared_error: 0.7275 - val_loss: 0.6393 - val_root_mean_squared_error: 0.7995
#
# Epoch 00006: val_root_mean_squared_error did not improve from 0.61766
# Epoch 7/100
# 17/17 - 21s - loss: 0.4821 - root_mean_squared_error: 0.6943 - val_loss: 0.5538 - val_root_mean_squared_error: 0.7442
#
# Epoch 00007: val_root_mean_squared_error did not improve from 0.61766
# Epoch 8/100
# 17/17 - 21s - loss: 0.5617 - root_mean_squared_error: 0.7494 - val_loss: 0.3420 - val_root_mean_squared_error: 0.5848
#
# Epoch 00008: val_root_mean_squared_error improved from 0.61766 to 0.58484, saving model to Roberta_Base_123_2.h5
# Epoch 9/100
# 17/17 - 21s - loss: 0.6032 - root_mean_squared_error: 0.7767 - val_loss: 0.5648 - val_root_mean_squared_error: 0.7515
#
# Epoch 00009: val_root_mean_squared_error did not improve from 0.58484
# Epoch 10/100
# 17/17 - 21s - loss: 0.3847 - root_mean_squared_error: 0.6202 - val_loss: 0.3856 - val_root_mean_squared_error: 0.6210
#
# Epoch 00010: val_root_mean_squared_error did not improve from 0.58484
# Epoch 11/100
# 17/17 - 21s - loss: 0.4310 - root_mean_squared_error: 0.6565 - val_loss: 0.5028 - val_root_mean_squared_error: 0.7091
#
# Epoch 00011: val_root_mean_squared_error did not improve from 0.58484
# Epoch 12/100
# 17/17 - 21s - loss: 0.3481 - root_mean_squared_error: 0.5900 - val_loss: 0.3700 - val_root_mean_squared_error: 0.6083
#
# Epoch 00012: val_root_mean_squared_error did not improve from 0.58484
# Epoch 13/100
# 17/17 - 21s - loss: 0.3295 - root_mean_squared_error: 0.5740 - val_loss: 0.2944 - val_root_mean_squared_error: 0.5425
#
# Epoch 00013: val_root_mean_squared_error improved from 0.58484 to 0.54255, saving model to Roberta_Base_123_2.h5
# Epoch 14/100
# 17/17 - 21s - loss: 0.4697 - root_mean_squared_error: 0.6854 - val_loss: 0.7351 - val_root_mean_squared_error: 0.8574
#
# Epoch 00014: val_root_mean_squared_error did not improve from 0.54255
# Epoch 15/100
# 17/17 - 21s - loss: 0.3163 - root_mean_squared_error: 0.5624 - val_loss: 0.2738 - val_root_mean_squared_error: 0.5233
#
# Epoch 00015: val_root_mean_squared_error improved from 0.54255 to 0.52330, saving model to Roberta_Base_123_2.h5
# Epoch 16/100
# 17/17 - 21s - loss: 0.3564 - root_mean_squared_error: 0.5970 - val_loss: 0.4116 - val_root_mean_squared_error: 0.6415
#
# Epoch 00016: val_root_mean_squared_error did not improve from 0.52330
# Epoch 17/100
# 17/17 - 21s - loss: 0.2906 - root_mean_squared_error: 0.5390 - val_loss: 0.2858 - val_root_mean_squared_error: 0.5346
#
# Epoch 00017: val_root_mean_squared_error did not improve from 0.52330
# Epoch 18/100
# 17/17 - 21s - loss: 0.3388 - root_mean_squared_error: 0.5820 - val_loss: 0.4353 - val_root_mean_squared_error: 0.6598
#
# Epoch 00018: val_root_mean_squared_error did not improve from 0.52330
# Epoch 19/100
# 17/17 - 21s - loss: 0.2671 - root_mean_squared_error: 0.5168 - val_loss: 0.3542 - val_root_mean_squared_error: 0.5951
#
# Epoch 00019: val_root_mean_squared_error did not improve from 0.52330
# Epoch 20/100
# 17/17 - 21s - loss: 0.2740 - root_mean_squared_error: 0.5235 - val_loss: 0.4809 - val_root_mean_squared_error: 0.6935
#
# Epoch 00020: val_root_mean_squared_error did not improve from 0.52330
# Epoch 21/100
# 17/17 - 21s - loss: 0.2733 - root_mean_squared_error: 0.5228 - val_loss: 0.3132 - val_root_mean_squared_error: 0.5596
#
# Epoch 00021: val_root_mean_squared_error did not improve from 0.52330
# Epoch 22/100
# 17/17 - 21s - loss: 0.2681 - root_mean_squared_error: 0.5178 - val_loss: 0.5552 - val_root_mean_squared_error: 0.7451
#
# Epoch 00022: val_root_mean_squared_error did not improve from 0.52330
# Epoch 23/100
# 17/17 - 21s - loss: 0.2433 - root_mean_squared_error: 0.4932 - val_loss: 0.2994 - val_root_mean_squared_error: 0.5472
#
# Epoch 00023: val_root_mean_squared_error did not improve from 0.52330
# Epoch 24/100
# 17/17 - 21s - loss: 0.2515 - root_mean_squared_error: 0.5015 - val_loss: 0.4329 - val_root_mean_squared_error: 0.6579
#
# Epoch 00024: val_root_mean_squared_error did not improve from 0.52330
# Epoch 25/100
# 17/17 - 21s - loss: 0.2404 - root_mean_squared_error: 0.4903 - val_loss: 0.2713 - val_root_mean_squared_error: 0.5209
#
# Epoch 00025: val_root_mean_squared_error improved from 0.52330 to 0.52090, saving model to Roberta_Base_123_2.h5
# Epoch 26/100
# 17/17 - 21s - loss: 0.2554 - root_mean_squared_error: 0.5054 - val_loss: 0.3118 - val_root_mean_squared_error: 0.5584
#
# Epoch 00026: val_root_mean_squared_error did not improve from 0.52090
# Epoch 27/100
# 17/17 - 21s - loss: 0.2594 - root_mean_squared_error: 0.5093 - val_loss: 0.2652 - val_root_mean_squared_error: 0.5150
#
# Epoch 00027: val_root_mean_squared_error improved from 0.52090 to 0.51501, saving model to Roberta_Base_123_2.h5
# Epoch 28/100
# 17/17 - 21s - loss: 0.2353 - root_mean_squared_error: 0.4850 - val_loss: 0.2918 - val_root_mean_squared_error: 0.5402
#
# Epoch 00028: val_root_mean_squared_error did not improve from 0.51501
# Epoch 29/100
# 17/17 - 21s - loss: 0.1998 - root_mean_squared_error: 0.4470 - val_loss: 0.2835 - val_root_mean_squared_error: 0.5325
#
# Epoch 00029: val_root_mean_squared_error did not improve from 0.51501
# Epoch 30/100
# 17/17 - 21s - loss: 0.2370 - root_mean_squared_error: 0.4868 - val_loss: 0.3262 - val_root_mean_squared_error: 0.5712
#
# Epoch 00030: val_root_mean_squared_error did not improve from 0.51501
# Epoch 31/100
# 17/17 - 21s - loss: 0.1860 - root_mean_squared_error: 0.4313 - val_loss: 0.3556 - val_root_mean_squared_error: 0.5964
#
# Epoch 00031: val_root_mean_squared_error did not improve from 0.51501
# Epoch 32/100
# 17/17 - 21s - loss: 0.2481 - root_mean_squared_error: 0.4981 - val_loss: 0.3585 - val_root_mean_squared_error: 0.5987
#
# Epoch 00032: val_root_mean_squared_error did not improve from 0.51501
# Epoch 33/100
# 17/17 - 21s - loss: 0.2090 - root_mean_squared_error: 0.4571 - val_loss: 0.4288 - val_root_mean_squared_error: 0.6548
#
# Epoch 00033: val_root_mean_squared_error did not improve from 0.51501
# Epoch 34/100
# 17/17 - 21s - loss: 0.2201 - root_mean_squared_error: 0.4691 - val_loss: 0.2652 - val_root_mean_squared_error: 0.5150
#
# Epoch 00034: val_root_mean_squared_error did not improve from 0.51501
# Epoch 35/100
# 17/17 - 21s - loss: 0.2188 - root_mean_squared_error: 0.4678 - val_loss: 0.3600 - val_root_mean_squared_error: 0.6000
#
# Epoch 00035: val_root_mean_squared_error did not improve from 0.51501
# Epoch 36/100
# 17/17 - 21s - loss: 0.2219 - root_mean_squared_error: 0.4710 - val_loss: 0.5853 - val_root_mean_squared_error: 0.7651
#
# Epoch 00036: val_root_mean_squared_error did not improve from 0.51501
# Epoch 37/100
# 17/17 - 21s - loss: 0.2259 - root_mean_squared_error: 0.4753 - val_loss: 0.2974 - val_root_mean_squared_error: 0.5454
#
# Epoch 00037: val_root_mean_squared_error did not improve from 0.51501
# Epoch 38/100
# 17/17 - 21s - loss: 0.1867 - root_mean_squared_error: 0.4321 - val_loss: 0.4361 - val_root_mean_squared_error: 0.6604
#
# Epoch 00038: val_root_mean_squared_error did not improve from 0.51501
# Epoch 39/100
# 17/17 - 21s - loss: 0.1873 - root_mean_squared_error: 0.4328 - val_loss: 0.3880 - val_root_mean_squared_error: 0.6229
#
# Epoch 00039: val_root_mean_squared_error did not improve from 0.51501
# Epoch 40/100
# 17/17 - 21s - loss: 0.1751 - root_mean_squared_error: 0.4185 - val_loss: 0.4465 - val_root_mean_squared_error: 0.6682
#
# Epoch 00040: val_root_mean_squared_error did not improve from 0.51501
# Epoch 41/100
# 17/17 - 21s - loss: 0.2418 - root_mean_squared_error: 0.4917 - val_loss: 0.1861 - val_root_mean_squared_error: 0.4313
#
# Epoch 00041: val_root_mean_squared_error improved from 0.51501 to 0.43134, saving model to Roberta_Base_123_2.h5
# Epoch 42/100
# 17/17 - 21s - loss: 0.2485 - root_mean_squared_error: 0.4985 - val_loss: 0.2956 - val_root_mean_squared_error: 0.5437
#
# Epoch 00042: val_root_mean_squared_error did not improve from 0.43134
# Epoch 43/100
# 17/17 - 21s - loss: 0.2132 - root_mean_squared_error: 0.4617 - val_loss: 0.2218 - val_root_mean_squared_error: 0.4710
#
# Epoch 00043: val_root_mean_squared_error did not improve from 0.43134
# Epoch 44/100
# 17/17 - 21s - loss: 0.2093 - root_mean_squared_error: 0.4575 - val_loss: 0.2337 - val_root_mean_squared_error: 0.4834
#
# Epoch 00044: val_root_mean_squared_error did not improve from 0.43134
# Epoch 45/100
# 17/17 - 21s - loss: 0.1486 - root_mean_squared_error: 0.3854 - val_loss: 0.2682 - val_root_mean_squared_error: 0.5179
#
# Epoch 00045: val_root_mean_squared_error did not improve from 0.43134
# Epoch 46/100
# 17/17 - 21s - loss: 0.1402 - root_mean_squared_error: 0.3744 - val_loss: 0.2779 - val_root_mean_squared_error: 0.5272
#
# Epoch 00046: val_root_mean_squared_error did not improve from 0.43134
# Epoch 47/100
# 17/17 - 21s - loss: 0.1362 - root_mean_squared_error: 0.3690 - val_loss: 0.2692 - val_root_mean_squared_error: 0.5189
#
# Epoch 00047: val_root_mean_squared_error did not improve from 0.43134
# Epoch 48/100
# 17/17 - 21s - loss: 0.1370 - root_mean_squared_error: 0.3702 - val_loss: 0.2100 - val_root_mean_squared_error: 0.4582
#
# Epoch 00048: val_root_mean_squared_error did not improve from 0.43134
# Epoch 49/100
# 17/17 - 21s - loss: 0.1499 - root_mean_squared_error: 0.3872 - val_loss: 0.2932 - val_root_mean_squared_error: 0.5415
#
# Epoch 00049: val_root_mean_squared_error did not improve from 0.43134
# Epoch 50/100
# 17/17 - 21s - loss: 0.1309 - root_mean_squared_error: 0.3619 - val_loss: 0.2772 - val_root_mean_squared_error: 0.5265
#
# Epoch 00050: val_root_mean_squared_error did not improve from 0.43134
# Epoch 51/100
# 17/17 - 21s - loss: 0.1115 - root_mean_squared_error: 0.3340 - val_loss: 0.2507 - val_root_mean_squared_error: 0.5007
#
# Epoch 00051: val_root_mean_squared_error did not improve from 0.43134
# Epoch 52/100
# 17/17 - 21s - loss: 0.1266 - root_mean_squared_error: 0.3558 - val_loss: 0.2921 - val_root_mean_squared_error: 0.5404
#
# Epoch 00052: val_root_mean_squared_error did not improve from 0.43134
# Epoch 53/100
# 17/17 - 21s - loss: 0.0976 - root_mean_squared_error: 0.3124 - val_loss: 0.3248 - val_root_mean_squared_error: 0.5699
#
# Epoch 00053: val_root_mean_squared_error did not improve from 0.43134
# Epoch 54/100
# 17/17 - 21s - loss: 0.1097 - root_mean_squared_error: 0.3312 - val_loss: 0.3693 - val_root_mean_squared_error: 0.6077
#
# Epoch 00054: val_root_mean_squared_error did not improve from 0.43134
# Epoch 55/100
# 17/17 - 21s - loss: 0.1445 - root_mean_squared_error: 0.3801 - val_loss: 0.1939 - val_root_mean_squared_error: 0.4403
#
# Epoch 00055: val_root_mean_squared_error did not improve from 0.43134
# Epoch 56/100
# 17/17 - 21s - loss: 0.1218 - root_mean_squared_error: 0.3490 - val_loss: 0.3032 - val_root_mean_squared_error: 0.5506
#
# Epoch 00056: val_root_mean_squared_error did not improve from 0.43134
# Epoch 57/100
# 17/17 - 21s - loss: 0.1463 - root_mean_squared_error: 0.3825 - val_loss: 0.4911 - val_root_mean_squared_error: 0.7008
#
# Epoch 00057: val_root_mean_squared_error did not improve from 0.43134
# Epoch 58/100
# 17/17 - 21s - loss: 0.1370 - root_mean_squared_error: 0.3701 - val_loss: 0.1750 - val_root_mean_squared_error: 0.4183
#
# Epoch 00058: val_root_mean_squared_error improved from 0.43134 to 0.41831, saving model to Roberta_Base_123_2.h5
# Epoch 59/100
# 17/17 - 21s - loss: 0.1159 - root_mean_squared_error: 0.3404 - val_loss: 0.2925 - val_root_mean_squared_error: 0.5408
#
# Epoch 00059: val_root_mean_squared_error did not improve from 0.41831
# Epoch 60/100
# 17/17 - 21s - loss: 0.1297 - root_mean_squared_error: 0.3602 - val_loss: 0.2083 - val_root_mean_squared_error: 0.4564
#
# Epoch 00060: val_root_mean_squared_error did not improve from 0.41831
# Epoch 61/100
# 17/17 - 21s - loss: 0.1198 - root_mean_squared_error: 0.3461 - val_loss: 0.2435 - val_root_mean_squared_error: 0.4935
#
# Epoch 00061: val_root_mean_squared_error did not improve from 0.41831
# Epoch 62/100
# 17/17 - 21s - loss: 0.1133 - root_mean_squared_error: 0.3366 - val_loss: 0.4059 - val_root_mean_squared_error: 0.6371
#
# Epoch 00062: val_root_mean_squared_error did not improve from 0.41831
# Epoch 63/100
# 17/17 - 21s - loss: 0.1281 - root_mean_squared_error: 0.3579 - val_loss: 0.4147 - val_root_mean_squared_error: 0.6440
#
# Epoch 00063: val_root_mean_squared_error did not improve from 0.41831
# Epoch 64/100
# 17/17 - 21s - loss: 0.1141 - root_mean_squared_error: 0.3378 - val_loss: 0.3853 - val_root_mean_squared_error: 0.6207
#
# Epoch 00064: val_root_mean_squared_error did not improve from 0.41831
# Epoch 65/100
# 17/17 - 21s - loss: 0.0991 - root_mean_squared_error: 0.3148 - val_loss: 0.3536 - val_root_mean_squared_error: 0.5946
#
# Epoch 00065: val_root_mean_squared_error did not improve from 0.41831
# Epoch 66/100
# 17/17 - 21s - loss: 0.0945 - root_mean_squared_error: 0.3074 - val_loss: 0.3205 - val_root_mean_squared_error: 0.5661
#
# Epoch 00066: val_root_mean_squared_error did not improve from 0.41831
# Epoch 67/100
# 17/17 - 21s - loss: 0.0895 - root_mean_squared_error: 0.2992 - val_loss: 0.2995 - val_root_mean_squared_error: 0.5473
#
# Epoch 00067: val_root_mean_squared_error did not improve from 0.41831
# Epoch 68/100
# 17/17 - 21s - loss: 0.0812 - root_mean_squared_error: 0.2849 - val_loss: 0.3545 - val_root_mean_squared_error: 0.5954
#
# Epoch 00068: val_root_mean_squared_error did not improve from 0.41831
# Epoch 69/100
# 17/17 - 21s - loss: 0.0753 - root_mean_squared_error: 0.2743 - val_loss: 0.3440 - val_root_mean_squared_error: 0.5865
#
# Epoch 00069: val_root_mean_squared_error did not improve from 0.41831
# Epoch 70/100
# 17/17 - 21s - loss: 0.0757 - root_mean_squared_error: 0.2752 - val_loss: 0.2185 - val_root_mean_squared_error: 0.4674
#
# Epoch 00070: val_root_mean_squared_error did not improve from 0.41831
# Epoch 71/100
# 17/17 - 21s - loss: 0.0853 - root_mean_squared_error: 0.2920 - val_loss: 0.1482 - val_root_mean_squared_error: 0.3849
#
# Epoch 00071: val_root_mean_squared_error improved from 0.41831 to 0.38494, saving model to Roberta_Base_123_2.h5
# Epoch 72/100
# 17/17 - 21s - loss: 0.1274 - root_mean_squared_error: 0.3569 - val_loss: 0.2346 - val_root_mean_squared_error: 0.4843
#
# Epoch 00072: val_root_mean_squared_error did not improve from 0.38494
# Epoch 73/100
# 17/17 - 21s - loss: 0.1016 - root_mean_squared_error: 0.3188 - val_loss: 0.4721 - val_root_mean_squared_error: 0.6871
#
# Epoch 00073: val_root_mean_squared_error did not improve from 0.38494
# Epoch 74/100
# 17/17 - 21s - loss: 0.0903 - root_mean_squared_error: 0.3005 - val_loss: 0.3070 - val_root_mean_squared_error: 0.5541
#
# Epoch 00074: val_root_mean_squared_error did not improve from 0.38494
# Epoch 75/100
# 17/17 - 21s - loss: 0.0811 - root_mean_squared_error: 0.2848 - val_loss: 0.2239 - val_root_mean_squared_error: 0.4732
#
# Epoch 00075: val_root_mean_squared_error did not improve from 0.38494
# Epoch 76/100
# 17/17 - 21s - loss: 0.0839 - root_mean_squared_error: 0.2897 - val_loss: 0.3696 - val_root_mean_squared_error: 0.6080
#
# Epoch 00076: val_root_mean_squared_error did not improve from 0.38494
# Epoch 77/100
# 17/17 - 21s - loss: 0.0741 - root_mean_squared_error: 0.2722 - val_loss: 0.3024 - val_root_mean_squared_error: 0.5499
#
# Epoch 00077: val_root_mean_squared_error did not improve from 0.38494
# Epoch 78/100
# 17/17 - 21s - loss: 0.0639 - root_mean_squared_error: 0.2528 - val_loss: 0.2954 - val_root_mean_squared_error: 0.5435
#
# Epoch 00078: val_root_mean_squared_error did not improve from 0.38494
# Epoch 79/100
# 17/17 - 21s - loss: 0.0718 - root_mean_squared_error: 0.2679 - val_loss: 0.2366 - val_root_mean_squared_error: 0.4864
#
# Epoch 00079: val_root_mean_squared_error did not improve from 0.38494
# Epoch 80/100
# 17/17 - 21s - loss: 0.0715 - root_mean_squared_error: 0.2675 - val_loss: 0.2486 - val_root_mean_squared_error: 0.4986
#
# Epoch 00080: val_root_mean_squared_error did not improve from 0.38494
# Epoch 81/100
# 17/17 - 21s - loss: 0.0836 - root_mean_squared_error: 0.2892 - val_loss: 0.3054 - val_root_mean_squared_error: 0.5526
#
# Epoch 00081: val_root_mean_squared_error did not improve from 0.38494
# Epoch 82/100
# 17/17 - 21s - loss: 0.0710 - root_mean_squared_error: 0.2665 - val_loss: 0.4125 - val_root_mean_squared_error: 0.6423
#
# Epoch 00082: val_root_mean_squared_error did not improve from 0.38494
# Epoch 83/100
# 17/17 - 21s - loss: 0.0753 - root_mean_squared_error: 0.2743 - val_loss: 0.2730 - val_root_mean_squared_error: 0.5225
#
# Epoch 00083: val_root_mean_squared_error did not improve from 0.38494
# Epoch 84/100
# 17/17 - 21s - loss: 0.0736 - root_mean_squared_error: 0.2713 - val_loss: 0.2651 - val_root_mean_squared_error: 0.5149
#
# Epoch 00084: val_root_mean_squared_error did not improve from 0.38494
# Epoch 85/100
# 17/17 - 21s - loss: 0.0663 - root_mean_squared_error: 0.2574 - val_loss: 0.3652 - val_root_mean_squared_error: 0.6044
#
# Epoch 00085: val_root_mean_squared_error did not improve from 0.38494
# Epoch 86/100
# 17/17 - 21s - loss: 0.0649 - root_mean_squared_error: 0.2547 - val_loss: 0.2241 - val_root_mean_squared_error: 0.4734
#
# Epoch 00086: val_root_mean_squared_error did not improve from 0.38494
# Epoch 87/100
# 17/17 - 21s - loss: 0.0719 - root_mean_squared_error: 0.2681 - val_loss: 0.3006 - val_root_mean_squared_error: 0.5483
#
# Epoch 00087: val_root_mean_squared_error did not improve from 0.38494
# Epoch 88/100
# 17/17 - 21s - loss: 0.0672 - root_mean_squared_error: 0.2592 - val_loss: 0.3017 - val_root_mean_squared_error: 0.5492
#
# Epoch 00088: val_root_mean_squared_error did not improve from 0.38494
# Epoch 89/100
# 17/17 - 21s - loss: 0.0690 - root_mean_squared_error: 0.2626 - val_loss: 0.3842 - val_root_mean_squared_error: 0.6199
#
# Epoch 00089: val_root_mean_squared_error did not improve from 0.38494
# Epoch 90/100
# 17/17 - 21s - loss: 0.0648 - root_mean_squared_error: 0.2546 - val_loss: 0.2862 - val_root_mean_squared_error: 0.5350
#
# Epoch 00090: val_root_mean_squared_error did not improve from 0.38494
# Epoch 91/100
# 17/17 - 21s - loss: 0.0708 - root_mean_squared_error: 0.2661 - val_loss: 0.1385 - val_root_mean_squared_error: 0.3721
#
# Epoch 00091: val_root_mean_squared_error improved from 0.38494 to 0.37215, saving model to Roberta_Base_123_2.h5
# Epoch 92/100
# 17/17 - 21s - loss: 0.0604 - root_mean_squared_error: 0.2457 - val_loss: 0.2399 - val_root_mean_squared_error: 0.4897
#
# Epoch 00092: val_root_mean_squared_error did not improve from 0.37215
# Epoch 93/100
# 17/17 - 21s - loss: 0.0669 - root_mean_squared_error: 0.2586 - val_loss: 0.1676 - val_root_mean_squared_error: 0.4094
#
# Epoch 00093: val_root_mean_squared_error did not improve from 0.37215
# Epoch 94/100
# 17/17 - 21s - loss: 0.0698 - root_mean_squared_error: 0.2642 - val_loss: 0.2505 - val_root_mean_squared_error: 0.5005
#
# Epoch 00094: val_root_mean_squared_error did not improve from 0.37215
# Epoch 95/100
# 17/17 - 21s - loss: 0.0760 - root_mean_squared_error: 0.2757 - val_loss: 0.4004 - val_root_mean_squared_error: 0.6328
#
# Epoch 00095: val_root_mean_squared_error did not improve from 0.37215
# Epoch 96/100
# 17/17 - 21s - loss: 0.0893 - root_mean_squared_error: 0.2988 - val_loss: 0.1755 - val_root_mean_squared_error: 0.4190
#
# Epoch 00096: val_root_mean_squared_error did not improve from 0.37215
# Epoch 97/100
# 17/17 - 21s - loss: 0.0646 - root_mean_squared_error: 0.2542 - val_loss: 0.2288 - val_root_mean_squared_error: 0.4783
#
# Epoch 00097: val_root_mean_squared_error did not improve from 0.37215
# Epoch 98/100
# 17/17 - 21s - loss: 0.0540 - root_mean_squared_error: 0.2323 - val_loss: 0.2825 - val_root_mean_squared_error: 0.5315
#
# Epoch 00098: val_root_mean_squared_error did not improve from 0.37215
# Epoch 99/100
# 17/17 - 21s - loss: 0.0531 - root_mean_squared_error: 0.2304 - val_loss: 0.3484 - val_root_mean_squared_error: 0.5902
#
# Epoch 00099: val_root_mean_squared_error did not improve from 0.37215
# Epoch 100/100
# 17/17 - 21s - loss: 0.0603 - root_mean_squared_error: 0.2457 - val_loss: 0.1532 - val_root_mean_squared_error: 0.3914
#
# Epoch 00100: val_root_mean_squared_error did not improve from 0.37215
#
#
# --------------------------------------------------
# Training fold 3
# Some layers from the model checkpoint at roberta-base were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at roberta-base.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Epoch 1/100
# 17/17 - 44s - loss: 1.3246 - root_mean_squared_error: 1.1509 - val_loss: 0.8830 - val_root_mean_squared_error: 0.9397
#
# Epoch 00001: val_root_mean_squared_error improved from inf to 0.93969, saving model to Roberta_Base_123_3.h5
# Epoch 2/100
# 17/17 - 21s - loss: 1.0052 - root_mean_squared_error: 1.0026 - val_loss: 0.7483 - val_root_mean_squared_error: 0.8650
#
# Epoch 00002: val_root_mean_squared_error improved from 0.93969 to 0.86502, saving model to Roberta_Base_123_3.h5
# Epoch 3/100
# 17/17 - 21s - loss: 0.7434 - root_mean_squared_error: 0.8622 - val_loss: 0.6538 - val_root_mean_squared_error: 0.8086
#
# Epoch 00003: val_root_mean_squared_error improved from 0.86502 to 0.80858, saving model to Roberta_Base_123_3.h5
# Epoch 4/100
# 17/17 - 21s - loss: 0.5087 - root_mean_squared_error: 0.7132 - val_loss: 0.4286 - val_root_mean_squared_error: 0.6547
#
# Epoch 00004: val_root_mean_squared_error improved from 0.80858 to 0.65469, saving model to Roberta_Base_123_3.h5
# Epoch 5/100
# 17/17 - 21s - loss: 0.6429 - root_mean_squared_error: 0.8018 - val_loss: 0.5267 - val_root_mean_squared_error: 0.7257
#
# Epoch 00005: val_root_mean_squared_error did not improve from 0.65469
# Epoch 6/100
# 17/17 - 21s - loss: 0.6943 - root_mean_squared_error: 0.8332 - val_loss: 0.3804 - val_root_mean_squared_error: 0.6168
#
# Epoch 00006: val_root_mean_squared_error improved from 0.65469 to 0.61676, saving model to Roberta_Base_123_3.h5
# Epoch 7/100
# 17/17 - 21s - loss: 0.5944 - root_mean_squared_error: 0.7710 - val_loss: 0.5747 - val_root_mean_squared_error: 0.7581
#
# Epoch 00007: val_root_mean_squared_error did not improve from 0.61676
# Epoch 8/100
# 17/17 - 21s - loss: 0.3889 - root_mean_squared_error: 0.6236 - val_loss: 0.3302 - val_root_mean_squared_error: 0.5746
#
# Epoch 00008: val_root_mean_squared_error improved from 0.61676 to 0.57465, saving model to Roberta_Base_123_3.h5
# Epoch 9/100
# 17/17 - 21s - loss: 0.3867 - root_mean_squared_error: 0.6219 - val_loss: 0.3268 - val_root_mean_squared_error: 0.5717
#
# Epoch 00009: val_root_mean_squared_error improved from 0.57465 to 0.57170, saving model to Roberta_Base_123_3.h5
# Epoch 10/100
# 17/17 - 21s - loss: 0.3037 - root_mean_squared_error: 0.5511 - val_loss: 0.3969 - val_root_mean_squared_error: 0.6300
#
# Epoch 00010: val_root_mean_squared_error did not improve from 0.57170
# Epoch 11/100
# 17/17 - 21s - loss: 0.3736 - root_mean_squared_error: 0.6112 - val_loss: 0.3817 - val_root_mean_squared_error: 0.6179
#
# Epoch 00011: val_root_mean_squared_error did not improve from 0.57170
# Epoch 12/100
# 17/17 - 21s - loss: 0.3536 - root_mean_squared_error: 0.5946 - val_loss: 0.3147 - val_root_mean_squared_error: 0.5610
#
# Epoch 00012: val_root_mean_squared_error improved from 0.57170 to 0.56099, saving model to Roberta_Base_123_3.h5
# Epoch 13/100
# 17/17 - 21s - loss: 0.3951 - root_mean_squared_error: 0.6286 - val_loss: 0.5364 - val_root_mean_squared_error: 0.7324
#
# Epoch 00013: val_root_mean_squared_error did not improve from 0.56099
# Epoch 14/100
# 17/17 - 21s - loss: 0.2779 - root_mean_squared_error: 0.5272 - val_loss: 0.3025 - val_root_mean_squared_error: 0.5500
#
# Epoch 00014: val_root_mean_squared_error improved from 0.56099 to 0.54999, saving model to Roberta_Base_123_3.h5
# Epoch 15/100
# 17/17 - 21s - loss: 0.3593 - root_mean_squared_error: 0.5994 - val_loss: 0.6253 - val_root_mean_squared_error: 0.7907
#
# Epoch 00015: val_root_mean_squared_error did not improve from 0.54999
# Epoch 16/100
# 17/17 - 21s - loss: 0.4010 - root_mean_squared_error: 0.6333 - val_loss: 0.3272 - val_root_mean_squared_error: 0.5721
#
# ...
#
# Epoch 00023: val_root_mean_squared_error did not improve from 0.52676
# Epoch 24/100
# 17/17 - 21s - loss: 0.3189 - root_mean_squared_error: 0.5647 - val_loss: 0.2938 - val_root_mean_squared_error: 0.5421
#
# Epoch 00024: val_root_mean_squared_error did not improve from 0.52676
# Epoch 25/100
# 17/17 - 21s - loss: 0.3642 - root_mean_squared_error: 0.6035 - val_loss: 0.3373 - val_root_mean_squared_error: 0.5808
#
# Epoch 00025: val_root_mean_squared_error did not improve from 0.52676
# Epoch 26/100
# 17/17 - 21s - loss: 0.2908 - root_mean_squared_error: 0.5392 - val_loss: 0.5024 - val_root_mean_squared_error: 0.7088
#
# Epoch 00026: val_root_mean_squared_error did not improve from 0.52676
# Epoch 27/100
# 17/17 - 21s - loss: 0.3484 - root_mean_squared_error: 0.5903 - val_loss: 0.2925 - val_root_mean_squared_error: 0.5408
#
# Epoch 00027: val_root_mean_squared_error did not improve from 0.52676
# Epoch 28/100
# 17/17 - 21s - loss: 0.2742 - root_mean_squared_error: 0.5237 - val_loss: 0.3844 - val_root_mean_squared_error: 0.6200
#
# Epoch 00028: val_root_mean_squared_error did not improve from 0.52676
# Epoch 29/100
# 17/17 - 21s - loss: 0.2877 - root_mean_squared_error: 0.5364 - val_loss: 0.3521 - val_root_mean_squared_error: 0.5933
#
# Epoch 00029: val_root_mean_squared_error did not improve from 0.52676
# Epoch 30/100
# 17/17 - 21s - loss: 0.2579 - root_mean_squared_error: 0.5078 - val_loss: 0.4020 - val_root_mean_squared_error: 0.6340
#
# Epoch 00030: val_root_mean_squared_error did not improve from 0.52676
# Epoch 31/100
# 17/17 - 21s - loss: 0.2473 - root_mean_squared_error: 0.4973 - val_loss: 0.3175 - val_root_mean_squared_error: 0.5635
#
# Epoch 00031: val_root_mean_squared_error did not improve from 0.52676
# Epoch 32/100
# 17/17 - 21s - loss: 0.2443 - root_mean_squared_error: 0.4943 - val_loss: 0.3411 - val_root_mean_squared_error: 0.5840
#
# Epoch 00032: val_root_mean_squared_error did not improve from 0.52676
# Epoch 33/100
# 17/17 - 21s - loss: 0.2271 - root_mean_squared_error: 0.4766 - val_loss: 0.3424 - val_root_mean_squared_error: 0.5851
#
# Epoch 00033: val_root_mean_squared_error did not improve from 0.52676
# Epoch 34/100
# 17/17 - 21s - loss: 0.2321 - root_mean_squared_error: 0.4818 - val_loss: 0.3990 - val_root_mean_squared_error: 0.6316
#
# Epoch 00034: val_root_mean_squared_error did not improve from 0.52676
# Epoch 35/100
# 17/17 - 21s - loss: 0.2109 - root_mean_squared_error: 0.4592 - val_loss: 0.4364 - val_root_mean_squared_error: 0.6606
#
# Epoch 00035: val_root_mean_squared_error did not improve from 0.52676
# Epoch 36/100
# 17/17 - 21s - loss: 0.2302 - root_mean_squared_error: 0.4798 - val_loss: 0.4912 - val_root_mean_squared_error: 0.7009
#
# Epoch 00036: val_root_mean_squared_error did not improve from 0.52676
# Epoch 37/100
# 17/17 - 21s - loss: 0.2623 - root_mean_squared_error: 0.5121 - val_loss: 0.4464 - val_root_mean_squared_error: 0.6681
#
# Epoch 00037: val_root_mean_squared_error did not improve from 0.52676
# Epoch 38/100
# 17/17 - 21s - loss: 0.2363 - root_mean_squared_error: 0.4861 - val_loss: 0.3474 - val_root_mean_squared_error: 0.5894
#
# Epoch 00038: val_root_mean_squared_error did not improve from 0.52676
# Epoch 39/100
# 17/17 - 21s - loss: 0.2059 - root_mean_squared_error: 0.4538 - val_loss: 0.4125 - val_root_mean_squared_error: 0.6423
#
# Epoch 00039: val_root_mean_squared_error did not improve from 0.52676
# Epoch 40/100
# 17/17 - 21s - loss: 0.2157 - root_mean_squared_error: 0.4645 - val_loss: 0.2839 - val_root_mean_squared_error: 0.5328
#
# Epoch 00040: val_root_mean_squared_error did not improve from 0.52676
# Epoch 41/100
# 17/17 - 21s - loss: 0.1779 - root_mean_squared_error: 0.4218 - val_loss: 0.6178 - val_root_mean_squared_error: 0.7860
#
# Epoch 00041: val_root_mean_squared_error did not improve from 0.52676
# Epoch 42/100
# 17/17 - 21s - loss: 0.2725 - root_mean_squared_error: 0.5221 - val_loss: 0.2651 - val_root_mean_squared_error: 0.5148
#
# Epoch 00042: val_root_mean_squared_error improved from 0.52676 to 0.51484, saving model to Roberta_Base_123_5.h5
# Epoch 43/100
# 17/17 - 21s - loss: 0.2606 - root_mean_squared_error: 0.5105 - val_loss: 0.4742 - val_root_mean_squared_error: 0.6886
#
# Epoch 00043: val_root_mean_squared_error did not improve from 0.51484
# Epoch 44/100
# 17/17 - 21s - loss: 0.2708 - root_mean_squared_error: 0.5204 - val_loss: 0.2399 - val_root_mean_squared_error: 0.4898
#
# Epoch 00044: val_root_mean_squared_error improved from 0.51484 to 0.48978, saving model to Roberta_Base_123_5.h5
# Epoch 45/100
# 17/17 - 21s - loss: 0.1892 - root_mean_squared_error: 0.4349 - val_loss: 0.3356 - val_root_mean_squared_error: 0.5793
#
# Epoch 00045: val_root_mean_squared_error did not improve from 0.48978
# Epoch 46/100
# 17/17 - 21s - loss: 0.1607 - root_mean_squared_error: 0.4009 - val_loss: 0.2951 - val_root_mean_squared_error: 0.5433
#
# Epoch 00046: val_root_mean_squared_error did not improve from 0.48978
# Epoch 47/100
# 17/17 - 21s - loss: 0.1765 - root_mean_squared_error: 0.4201 - val_loss: 0.2271 - val_root_mean_squared_error: 0.4765
#
# Epoch 00047: val_root_mean_squared_error improved from 0.48978 to 0.47652, saving model to Roberta_Base_123_5.h5
# Epoch 48/100
# 17/17 - 21s - loss: 0.1612 - root_mean_squared_error: 0.4016 - val_loss: 0.3716 - val_root_mean_squared_error: 0.6096
#
# Epoch 00048: val_root_mean_squared_error did not improve from 0.47652
# Epoch 49/100
# 17/17 - 21s - loss: 0.1520 - root_mean_squared_error: 0.3898 - val_loss: 0.2948 - val_root_mean_squared_error: 0.5429
#
# Epoch 00049: val_root_mean_squared_error did not improve from 0.47652
# Epoch 50/100
# 17/17 - 21s - loss: 0.1471 - root_mean_squared_error: 0.3835 - val_loss: 0.4665 - val_root_mean_squared_error: 0.6830
#
# Epoch 00050: val_root_mean_squared_error did not improve from 0.47652
# Epoch 51/100
# 17/17 - 21s - loss: 0.2123 - root_mean_squared_error: 0.4607 - val_loss: 0.1946 - val_root_mean_squared_error: 0.4411
#
# Epoch 00051: val_root_mean_squared_error improved from 0.47652 to 0.44109, saving model to Roberta_Base_123_5.h5
# Epoch 52/100
# 17/17 - 21s - loss: 0.1991 - root_mean_squared_error: 0.4462 - val_loss: 0.3004 - val_root_mean_squared_error: 0.5481
#
# Epoch 00052: val_root_mean_squared_error did not improve from 0.44109
# Epoch 53/100
# 17/17 - 21s - loss: 0.1796 - root_mean_squared_error: 0.4238 - val_loss: 0.3101 - val_root_mean_squared_error: 0.5569
#
# Epoch 00053: val_root_mean_squared_error did not improve from 0.44109
# Epoch 54/100
# 17/17 - 21s - loss: 0.1577 - root_mean_squared_error: 0.3971 - val_loss: 0.2699 - val_root_mean_squared_error: 0.5195
#
# Epoch 00054: val_root_mean_squared_error did not improve from 0.44109
# Epoch 55/100
# 17/17 - 21s - loss: 0.1294 - root_mean_squared_error: 0.3597 - val_loss: 0.3950 - val_root_mean_squared_error: 0.6285
#
# Epoch 00055: val_root_mean_squared_error did not improve from 0.44109
# Epoch 56/100
# 17/17 - 21s - loss: 0.1581 - root_mean_squared_error: 0.3976 - val_loss: 0.3772 - val_root_mean_squared_error: 0.6142
#
# Epoch 00056: val_root_mean_squared_error did not improve from 0.44109
# Epoch 57/100
# 17/17 - 21s - loss: 0.1873 - root_mean_squared_error: 0.4327 - val_loss: 0.5094 - val_root_mean_squared_error: 0.7137
#
# Epoch 00057: val_root_mean_squared_error did not improve from 0.44109
# Epoch 58/100
# 17/17 - 21s - loss: 0.1974 - root_mean_squared_error: 0.4443 - val_loss: 0.2185 - val_root_mean_squared_error: 0.4675
#
# Epoch 00058: val_root_mean_squared_error did not improve from 0.44109
# Epoch 59/100
# 17/17 - 21s - loss: 0.1547 - root_mean_squared_error: 0.3933 - val_loss: 0.4165 - val_root_mean_squared_error: 0.6453
#
# Epoch 00059: val_root_mean_squared_error did not improve from 0.44109
# Epoch 60/100
# 17/17 - 21s - loss: 0.1793 - root_mean_squared_error: 0.4235 - val_loss: 0.2117 - val_root_mean_squared_error: 0.4601
#
# Epoch 00060: val_root_mean_squared_error did not improve from 0.44109
# Epoch 61/100
# 17/17 - 21s - loss: 0.1639 - root_mean_squared_error: 0.4048 - val_loss: 0.2503 - val_root_mean_squared_error: 0.5003
#
# Epoch 00061: val_root_mean_squared_error did not improve from 0.44109
# Epoch 62/100
# 17/17 - 21s - loss: 0.1382 - root_mean_squared_error: 0.3717 - val_loss: 0.2866 - val_root_mean_squared_error: 0.5353
#
# Epoch 00062: val_root_mean_squared_error did not improve from 0.44109
# Epoch 63/100
# 17/17 - 21s - loss: 0.1283 - root_mean_squared_error: 0.3582 - val_loss: 0.3985 - val_root_mean_squared_error: 0.6313
#
# Epoch 00063: val_root_mean_squared_error did not improve from 0.44109
# Epoch 64/100
# 17/17 - 21s - loss: 0.1415 - root_mean_squared_error: 0.3761 - val_loss: 0.2713 - val_root_mean_squared_error: 0.5209
#
# Epoch 00064: val_root_mean_squared_error did not improve from 0.44109
# Epoch 65/100
# 17/17 - 21s - loss: 0.1009 - root_mean_squared_error: 0.3177 - val_loss: 0.2625 - val_root_mean_squared_error: 0.5123
#
# Epoch 00065: val_root_mean_squared_error did not improve from 0.44109
# Epoch 66/100
# 17/17 - 21s - loss: 0.0971 - root_mean_squared_error: 0.3116 - val_loss: 0.3296 - val_root_mean_squared_error: 0.5742
#
# Epoch 00066: val_root_mean_squared_error did not improve from 0.44109
# Epoch 67/100
# 17/17 - 21s - loss: 0.0999 - root_mean_squared_error: 0.3161 - val_loss: 0.2006 - val_root_mean_squared_error: 0.4479
#
# Epoch 00067: val_root_mean_squared_error did not improve from 0.44109
# Epoch 68/100
# 17/17 - 21s - loss: 0.1150 - root_mean_squared_error: 0.3392 - val_loss: 0.1923 - val_root_mean_squared_error: 0.4385
#
# Epoch 00068: val_root_mean_squared_error improved from 0.44109 to 0.43854, saving model to Roberta_Base_123_5.h5
# Epoch 69/100
# 17/17 - 21s - loss: 0.1108 - root_mean_squared_error: 0.3329 - val_loss: 0.2784 - val_root_mean_squared_error: 0.5276
#
# Epoch 00069: val_root_mean_squared_error did not improve from 0.43854
# Epoch 70/100
# 17/17 - 21s - loss: 0.1021 - root_mean_squared_error: 0.3195 - val_loss: 0.3043 - val_root_mean_squared_error: 0.5516
#
# Epoch 00070: val_root_mean_squared_error did not improve from 0.43854
# Epoch 71/100
# 17/17 - 21s - loss: 0.1151 - root_mean_squared_error: 0.3393 - val_loss: 0.2654 - val_root_mean_squared_error: 0.5152
#
# Epoch 00071: val_root_mean_squared_error did not improve from 0.43854
# Epoch 72/100
# 17/17 - 21s - loss: 0.0933 - root_mean_squared_error: 0.3055 - val_loss: 0.2995 - val_root_mean_squared_error: 0.5473
#
# Epoch 00072: val_root_mean_squared_error did not improve from 0.43854
# Epoch 73/100
# 17/17 - 21s - loss: 0.1011 - root_mean_squared_error: 0.3180 - val_loss: 0.2807 - val_root_mean_squared_error: 0.5298
#
# Epoch 00073: val_root_mean_squared_error did not improve from 0.43854
# Epoch 74/100
# 17/17 - 21s - loss: 0.1049 - root_mean_squared_error: 0.3238 - val_loss: 0.2594 - val_root_mean_squared_error: 0.5093
#
# Epoch 00074: val_root_mean_squared_error did not improve from 0.43854
# Epoch 75/100
# 17/17 - 21s - loss: 0.0990 - root_mean_squared_error: 0.3146 - val_loss: 0.2315 - val_root_mean_squared_error: 0.4811
#
# Epoch 00075: val_root_mean_squared_error did not improve from 0.43854
# Epoch 76/100
# 17/17 - 21s - loss: 0.1074 - root_mean_squared_error: 0.3276 - val_loss: 0.2632 - val_root_mean_squared_error: 0.5130
#
# Epoch 00076: val_root_mean_squared_error did not improve from 0.43854
# Epoch 77/100
# 17/17 - 21s - loss: 0.0969 - root_mean_squared_error: 0.3113 - val_loss: 0.2700 - val_root_mean_squared_error: 0.5196
#
# Epoch 00077: val_root_mean_squared_error did not improve from 0.43854
# Epoch 78/100
# 17/17 - 21s - loss: 0.0906 - root_mean_squared_error: 0.3010 - val_loss: 0.2742 - val_root_mean_squared_error: 0.5237
#
# Epoch 00078: val_root_mean_squared_error did not improve from 0.43854
# Epoch 79/100
# 17/17 - 21s - loss: 0.0960 - root_mean_squared_error: 0.3099 - val_loss: 0.3178 - val_root_mean_squared_error: 0.5637
#
# Epoch 00079: val_root_mean_squared_error did not improve from 0.43854
# Epoch 80/100
# 17/17 - 21s - loss: 0.0947 - root_mean_squared_error: 0.3077 - val_loss: 0.1962 - val_root_mean_squared_error: 0.4429
#
# Epoch 00080: val_root_mean_squared_error did not improve from 0.43854
# Epoch 81/100
# 17/17 - 21s - loss: 0.0826 - root_mean_squared_error: 0.2875 - val_loss: 0.1541 - val_root_mean_squared_error: 0.3926
#
# Epoch 00081: val_root_mean_squared_error improved from 0.43854 to 0.39262, saving model to Roberta_Base_123_5.h5
# Epoch 82/100
# 17/17 - 21s - loss: 0.1127 - root_mean_squared_error: 0.3358 - val_loss: 0.1905 - val_root_mean_squared_error: 0.4365
#
# Epoch 00082: val_root_mean_squared_error did not improve from 0.39262
# Epoch 83/100
# 17/17 - 21s - loss: 0.1244 - root_mean_squared_error: 0.3527 - val_loss: 0.2707 - val_root_mean_squared_error: 0.5202
#
# Epoch 00083: val_root_mean_squared_error did not improve from 0.39262
# Epoch 84/100
# 17/17 - 21s - loss: 0.0820 - root_mean_squared_error: 0.2863 - val_loss: 0.2921 - val_root_mean_squared_error: 0.5405
#
# Epoch 00084: val_root_mean_squared_error did not improve from 0.39262
# Epoch 85/100
# 17/17 - 21s - loss: 0.0939 - root_mean_squared_error: 0.3064 - val_loss: 0.3275 - val_root_mean_squared_error: 0.5723
#
# Epoch 00085: val_root_mean_squared_error did not improve from 0.39262
# Epoch 86/100
# 17/17 - 21s - loss: 0.0977 - root_mean_squared_error: 0.3126 - val_loss: 0.2555 - val_root_mean_squared_error: 0.5055
#
# Epoch 00086: val_root_mean_squared_error did not improve from 0.39262
# Epoch 87/100
# 17/17 - 21s - loss: 0.0759 - root_mean_squared_error: 0.2755 - val_loss: 0.2233 - val_root_mean_squared_error: 0.4725
#
# Epoch 00087: val_root_mean_squared_error did not improve from 0.39262
# Epoch 88/100
# 17/17 - 21s - loss: 0.0738 - root_mean_squared_error: 0.2717 - val_loss: 0.2129 - val_root_mean_squared_error: 0.4614
#
# Epoch 00088: val_root_mean_squared_error did not improve from 0.39262
# Epoch 89/100
# 17/17 - 21s - loss: 0.0724 - root_mean_squared_error: 0.2690 - val_loss: 0.3360 - val_root_mean_squared_error: 0.5797
#
# Epoch 00089: val_root_mean_squared_error did not improve from 0.39262
# Epoch 90/100
# 17/17 - 21s - loss: 0.0724 - root_mean_squared_error: 0.2691 - val_loss: 0.2605 - val_root_mean_squared_error: 0.5104
#
# Epoch 00090: val_root_mean_squared_error did not improve from 0.39262
# Epoch 91/100
# 17/17 - 21s - loss: 0.0719 - root_mean_squared_error: 0.2681 - val_loss: 0.2223 - val_root_mean_squared_error: 0.4715
#
# Epoch 00091: val_root_mean_squared_error did not improve from 0.39262
# Epoch 92/100
# 17/17 - 21s - loss: 0.0603 - root_mean_squared_error: 0.2455 - val_loss: 0.2070 - val_root_mean_squared_error: 0.4550
#
# Epoch 00092: val_root_mean_squared_error did not improve from 0.39262
# Epoch 93/100
# 17/17 - 21s - loss: 0.0703 - root_mean_squared_error: 0.2651 - val_loss: 0.2078 - val_root_mean_squared_error: 0.4558
#
# Epoch 00093: val_root_mean_squared_error did not improve from 0.39262
# Epoch 94/100
# 17/17 - 21s - loss: 0.0865 - root_mean_squared_error: 0.2941 - val_loss: 0.3392 - val_root_mean_squared_error: 0.5824
#
# Epoch 00094: val_root_mean_squared_error did not improve from 0.39262
# Epoch 95/100
# 17/17 - 21s - loss: 0.0720 - root_mean_squared_error: 0.2683 - val_loss: 0.1996 - val_root_mean_squared_error: 0.4468
#
# Epoch 00095: val_root_mean_squared_error did not improve from 0.39262
# Epoch 96/100
# 17/17 - 21s - loss: 0.0752 - root_mean_squared_error: 0.2743 - val_loss: 0.1965 - val_root_mean_squared_error: 0.4433
#
# Epoch 00096: val_root_mean_squared_error did not improve from 0.39262
# Epoch 97/100
# 17/17 - 21s - loss: 0.0645 - root_mean_squared_error: 0.2541 - val_loss: 0.2180 - val_root_mean_squared_error: 0.4669
#
# Epoch 00097: val_root_mean_squared_error did not improve from 0.39262
# Epoch 98/100
# 17/17 - 21s - loss: 0.0739 - root_mean_squared_error: 0.2719 - val_loss: 0.2117 - val_root_mean_squared_error: 0.4601
#
# Epoch 00098: val_root_mean_squared_error did not improve from 0.39262
# Epoch 99/100
# 17/17 - 21s - loss: 0.0597 - root_mean_squared_error: 0.2443 - val_loss: 0.2157 - val_root_mean_squared_error: 0.4644
#
# Epoch 00099: val_root_mean_squared_error did not improve from 0.39262
# Epoch 100/100
# 17/17 - 21s - loss: 0.0672 - root_mean_squared_error: 0.2592 - val_loss: 0.1890 - val_root_mean_squared_error: 0.4347
#
# Epoch 00100: val_root_mean_squared_error did not improve from 0.39262
#
#
# --------------------------------------------------
# Our out of folds RMSE is 0.40686363577376905
