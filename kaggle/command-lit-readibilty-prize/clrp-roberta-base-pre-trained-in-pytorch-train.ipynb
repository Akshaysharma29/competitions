# %% [markdown]
# # Overview
# This is kernel is almost the same as [Lightweight Roberta solution in PyTorch](https://www.kaggle.com/andretugan/lightweight-roberta-solution-in-pytorch), but instead of "roberta-base", it starts from [Maunish's pre-trained model](https://www.kaggle.com/maunish/clrp-roberta-base).
#
# Acknowledgments: some ideas were taken from kernels by [Torch](https://www.kaggle.com/rhtsingh) and [Maunish](https://www.kaggle.com/maunish).

# %%
# !git init
# !curl -s https://packagecloud.io/install/repositories/github/git-lfs/script.deb.sh | bash
# !apt-get install git-lfs
# !git lfs install
# !git clone https://huggingface.co/roberta-base

# !git clone https://huggingface.co/roberta-large
# !git clone https://huggingface.co/facebook/bart-base
# !git clone https://huggingface.co/bert-base-uncased
# !git clone https://huggingface.co/microsoft/deberta-base
# !git clone https://huggingface.co/distilroberta-base
# Out:
# Initialized empty Git repository in /kaggle/working/.git/
# Detected operating system as Ubuntu/bionic.
# Checking for curl...
# Detected curl...
# Checking for gpg...
# Detected gpg...
# Running apt-get update... done.
# Installing apt-transport-https... done.
# Installing /etc/apt/sources.list.d/github_git-lfs.list...done.
# Importing packagecloud gpg key... done.
# Running apt-get update... done.
#
# The repository is setup! You can now install packages.
#
#
#
# The following NEW packages will be installed:
#   git-lfs
# 0 upgraded, 1 newly installed, 0 to remove and 52 not upgraded.
# Need to get 2129 kB of archives.
# After this operation, 7662 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 git-lfs amd64 2.3.4-1 [2129 kB]
# Fetched 2129 kB in 1s (1584 kB/s)
# debconf: delaying package configuration, since apt-utils is not installed
# Selecting previously unselected package git-lfs.
# (Reading database ... 100757 files and directories currently installed.)
# Preparing to unpack .../git-lfs_2.3.4-1_amd64.deb ...
# Unpacking git-lfs (2.3.4-1) ...
# Setting up git-lfs (2.3.4-1) ...
# Updated git hooks.
# Git LFS initialized.
# Cloning into 'roberta-base'...
# remote: Enumerating objects: 74, done.
# remote: Counting objects: 100% (74/74), done.
# remote: Compressing objects: 100% (73/73), done.
# remote: Total 74 (delta 32), reused 0 (delta 0)
# Unpacking objects: 100% (74/74), done.
# Filtering content: 100% (4/4), 2.15 GiB | 62.90 MiB/s, done.

# %%
import os
import math
import random
import time

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from transformers import AdamW
from transformers import AutoTokenizer
from transformers import AutoModel
from transformers import AutoConfig
from transformers import get_cosine_schedule_with_warmup

from sklearn.model_selection import KFold

import gc
gc.enable()

# %%
NUM_FOLDS = 7#6#10#9#8#7#6#5
NUM_EPOCHS = 3
BATCH_SIZE = 16#4#16#24#32#16#1
MAX_LEN = 300#248
EVAL_SCHEDULE = [(0.50, 16), (0.49, 8), (0.48, 4), (0.47, 2), (-1., 1)]
ROBERTA_PATH = "../input/clrp-roberta-base/clrp_roberta_base"#"../input/clrp-roberta-base/clrp_roberta_base"
TOKENIZER_PATH = "./roberta-large"#"../input/clrp-roberta-base/clrp_roberta_base"
CONFIG_PATH = "../input/clrp-roberta-base/clrp_roberta_base"
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# %%
def set_random_seed(random_seed):
    random.seed(random_seed)
    np.random.seed(random_seed)
    os.environ["PYTHONHASHSEED"] = str(random_seed)

    torch.manual_seed(random_seed)
    torch.cuda.manual_seed(random_seed)
    torch.cuda.manual_seed_all(random_seed)

    torch.backends.cudnn.deterministic = True

# %%
train_df = pd.read_csv("/kaggle/input/commonlitreadabilityprize/train.csv")

# Remove incomplete entries if any.
train_df.drop(train_df[(train_df.target == 0) & (train_df.standard_error == 0)].index,
              inplace=True)
train_df.reset_index(drop=True, inplace=True)

test_df = pd.read_csv("/kaggle/input/commonlitreadabilityprize/test.csv")
submission_df = pd.read_csv("/kaggle/input/commonlitreadabilityprize/sample_submission.csv")

# %%
tokenizer = AutoTokenizer.from_pretrained(TOKENIZER_PATH)
# Out:
# Downloading:   0%|          | 0.00/482 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %% [markdown]
# # Dataset

# %%
class LitDataset(Dataset):
    def __init__(self, df, inference_only=False):
        super().__init__()

        self.df = df        
        self.inference_only = inference_only
        self.text = df.excerpt.tolist()
        #self.text = [text.replace("\n", " ") for text in self.text]
        
        if not self.inference_only:
            self.target = torch.tensor(df.target.values, dtype=torch.float32)        
    
        self.encoded = tokenizer.batch_encode_plus(
            self.text,
            padding = 'max_length',            
            max_length = MAX_LEN,
            truncation = True,
            return_attention_mask=True
        )        
 

    def __len__(self):
        return len(self.df)

    
    def __getitem__(self, index):        
        input_ids = torch.tensor(self.encoded['input_ids'][index])
        attention_mask = torch.tensor(self.encoded['attention_mask'][index])
        
        if self.inference_only:
            return (input_ids, attention_mask)            
        else:
            target = self.target[index]
            return (input_ids, attention_mask, target)

# %% [markdown]
# # Model
# The model is inspired by the one from [Maunish](https://www.kaggle.com/maunish/clrp-roberta-svm).

# %%
# class LitModel(nn.Module):
#     def __init__(self):
#         super().__init__()

#         config = AutoConfig.from_pretrained(CONFIG_PATH)
#         config.update({"output_hidden_states":True, 
#                        "hidden_dropout_prob": 0.0,
# #                        "attention_probs_dropout_prob":0.0,
#                        "layer_norm_eps": 1e-7})                       
        
#         self.roberta = AutoModel.from_pretrained(ROBERTA_PATH, config=config)  
            
#         self.attention = nn.Sequential(            
#             nn.Linear(768, 512),            
#             nn.Tanh(),  
#             nn.Linear(512, 1),
#             nn.Softmax(dim=1)
#         )        

#         self.regressor = nn.Sequential(      
# #             nn.LayerNorm(768),
#             nn.Linear(768, 1),          
#         )
        

#     def forward(self, input_ids, attention_mask):
#         roberta_output = self.roberta(input_ids=input_ids,
#                                       attention_mask=attention_mask)        

#         # There are a total of 13 layers of hidden states.
#         # 1 for the embedding layer, and 12 for the 12 Roberta layers.
#         # We take the hidden states from the last Roberta layer.
#         last_layer_hidden_states = roberta_output.hidden_states[-1]

#         # The number of cells is MAX_LEN.
#         # The size of the hidden state of each cell is 768 (for roberta-base).
#         # In order to condense hidden states of all cells to a context vector,
#         # we compute a weighted average of the hidden states of all cells.
#         # We compute the weight of each cell, using the attention neural network.
#         weights = self.attention(last_layer_hidden_states)
                
#         # weights.shape is BATCH_SIZE x MAX_LEN x 1
#         # last_layer_hidden_states.shape is BATCH_SIZE x MAX_LEN x 768        
#         # Now we compute context_vector as the weighted average.
#         # context_vector.shape is BATCH_SIZE x 768
#         context_vector = torch.sum(weights * last_layer_hidden_states, dim=1)        
        
#         # Now we reduce the context vector to the prediction score.
#         return self.regressor(context_vector)

# %%
# class LitModel(nn.Module):
#     def __init__(self):
#         super().__init__()

#         config = AutoConfig.from_pretrained(CONFIG_PATH)
#         config.update({"output_hidden_states":True, 
#                        "hidden_dropout_prob": 0.0,
# #                        "attention_probs_dropout_prob":0.0,
#                        "layer_norm_eps": 1e-7})                       
        
#         self.roberta = AutoModel.from_pretrained(ROBERTA_PATH, config=config)  
#         self.cnn1 = nn.Conv1d(768, MAX_LEN, kernel_size=2, padding=1)
#         self.cnn2 = nn.Conv1d(MAX_LEN, 1, kernel_size=2, padding=1)

        

#     def forward(self, input_ids, attention_mask):
#         roberta_output = self.roberta(input_ids=input_ids,
#                                       attention_mask=attention_mask)        
#         last_hidden_state = roberta_output[0]
#         last_hidden_state = last_hidden_state.permute(0, 2, 1)
#         cnn_embeddings = F.relu(self.cnn1(last_hidden_state))
#         cnn_embeddings = self.cnn2(cnn_embeddings)
#         logits, _ = torch.max(cnn_embeddings, 2)
#         return logits

# %%
# https://arxiv.org/pdf/2103.04083v1.pdf
class LitModel(nn.Module):  
    def __init__(self):
        super().__init__()

        config = AutoConfig.from_pretrained(CONFIG_PATH)
        config.update({"output_hidden_states":True, 
                       "hidden_dropout_prob": 0.0,
#                        "attention_probs_dropout_prob":0.0,
                       "layer_norm_eps": 1e-7})                       
        
        self.roberta = AutoModel.from_pretrained(ROBERTA_PATH, config=config)  
#         self.cnn1 = nn.Conv1d(768, MAX_LEN, kernel_size=1)
#         self.cnn2 = nn.Conv1d(MAX_LEN, 1, kernel_size=1)
        self.cnn1 = nn.Conv1d(768, 512, kernel_size=1)
        self.cnn2 = nn.Conv1d(512, MAX_LEN, kernel_size=1)
         
#         self.layernorm = nn.LayerNorm(MAX_LEN,MAX_LEN)    
        self.layernorm = nn.LayerNorm(MAX_LEN)
            
        self.attention = nn.Sequential(            
            nn.Linear(MAX_LEN, MAX_LEN),            
            nn.Tanh(),  
            nn.Linear(MAX_LEN, 1),
            nn.Softmax(dim=1)
        )        

        self.regressor = nn.Sequential(      
#             nn.LayerNorm(768),
            nn.Linear(MAX_LEN, 1),          
        )
        

    def forward(self, input_ids, attention_mask):
        roberta_output = self.roberta(input_ids=input_ids,
                                      attention_mask=attention_mask)   
        last_hidden_state = roberta_output.hidden_states[-1]
#         print(last_hidden_state.shape)
        last_hidden_state = last_hidden_state.permute(0, 2, 1)#16*1024*MAX_LEN
#         print(last_hidden_state.shape)
        cnn_embeddings = F.relu(self.cnn1(last_hidden_state))#16*512*MAX_LEN
#         print(cnn_embeddings.shape)
        cnn_embeddings = self.cnn2(cnn_embeddings)#16*MAX_LEN(embedding)*MAX_LEN(tokens)
#         print(cnn_embeddings.shape)
        cnn_embeddings = cnn_embeddings.permute(0, 2, 1)
#         cnn_embeddings = self.layernorm(cnn_embeddings)
#         print(cnn_embeddings.shape)
        # There are a total of 13 layers of hidden states.
        # 1 for the embedding layer, and 12 for the 12 Roberta layers.
        # We take the hidden states from the last Roberta layer.
#         last_layer_hidden_states = roberta_output.hidden_states[-1]
        

        # The number of cells is MAX_LEN.
        # The size of the hidden state of each cell is 768 (for roberta-base).
        # In order to condense hidden states of all cells to a context vector,
        # we compute a weighted average of the hidden states of all cells.
        # We compute the weight of each cell, using the attention neural network.
#         print(cnn_embeddings.shape)
        weights = self.attention(cnn_embeddings)#16*MAX_LEN*1
#         print('weights.shape',weights.shape)
                
        # weights.shape is BATCH_SIZE x MAX_LEN x 1
        # last_layer_hidden_states.shape is BATCH_SIZE x MAX_LEN x 768        
        # Now we compute context_vector as the weighted average.
        # context_vector.shape is BATCH_SIZE x 768
        context_vector = torch.sum(weights * cnn_embeddings, dim=1)#16*MAX_LEN   
#         print('context_vector',context_vector.shape)
        
        # Now we reduce the context vector to the prediction score.
        return self.regressor(context_vector)#16

# %%
def eval_mse(model, data_loader):
    """Evaluates the mean squared error of the |model| on |data_loader|"""
    model.eval()            
    mse_sum = 0

    with torch.no_grad():
        for batch_num, (input_ids, attention_mask, target) in enumerate(data_loader):
            input_ids = input_ids.to(DEVICE)
            attention_mask = attention_mask.to(DEVICE)                        
            target = target.to(DEVICE)           
            
            pred = model(input_ids, attention_mask)                       

            mse_sum += nn.MSELoss(reduction="sum")(pred.flatten(), target).item()
                

    return mse_sum / len(data_loader.dataset)

# %%
def predict(model, data_loader):
    """Returns an np.array with predictions of the |model| on |data_loader|"""
    model.eval()

    result = np.zeros(len(data_loader.dataset))    
    index = 0
    
    with torch.no_grad():
        for batch_num, (input_ids, attention_mask) in enumerate(data_loader):
            input_ids = input_ids.to(DEVICE)
            attention_mask = attention_mask.to(DEVICE)
                        
            pred = model(input_ids, attention_mask)                        

            result[index : index + pred.shape[0]] = pred.flatten().to("cpu")
            index += pred.shape[0]

    return result

# %%
def train(model, model_path, train_loader, val_loader,
          optimizer, scheduler=None, num_epochs=NUM_EPOCHS):    
    best_val_rmse = None
    best_epoch = 0
    step = 0
    last_eval_step = 0
    eval_period = EVAL_SCHEDULE[0][1]    

    start = time.time()

    for epoch in range(num_epochs):                           
        val_rmse = None         

        for batch_num, (input_ids, attention_mask, target) in enumerate(train_loader):
            input_ids = input_ids.to(DEVICE)
            attention_mask = attention_mask.to(DEVICE)            
            target = target.to(DEVICE)                        

            optimizer.zero_grad()
            
            model.train()

            pred = model(input_ids, attention_mask)
                                                        
            mse = nn.MSELoss(reduction="mean")(pred.flatten(), target)
                        
            mse.backward()

            optimizer.step()
            if scheduler:
                scheduler.step()
            
            if step >= last_eval_step + eval_period:
                # Evaluate the model on val_loader.
                elapsed_seconds = time.time() - start
                num_steps = step - last_eval_step
                print(f"\n{num_steps} steps took {elapsed_seconds:0.3} seconds")
                last_eval_step = step
                
                val_rmse = math.sqrt(eval_mse(model, val_loader))                            

                print(f"Epoch: {epoch} batch_num: {batch_num}", 
                      f"val_rmse: {val_rmse:0.4}")

                for rmse, period in EVAL_SCHEDULE:
                    if val_rmse >= rmse:
                        eval_period = period
                        break                               
                
                if not best_val_rmse or val_rmse < best_val_rmse:                    
                    best_val_rmse = val_rmse
                    best_epoch = epoch
                    torch.save(model.state_dict(), model_path)
                    print(f"New best_val_rmse: {best_val_rmse:0.4}")
                else:       
                    print(f"Still best_val_rmse: {best_val_rmse:0.4}",
                          f"(from epoch {best_epoch})")                                    
                    
                start = time.time()
                                            
            step += 1
                        
    
    return best_val_rmse

# %%
def create_optimizer(model):
    named_parameters = list(model.named_parameters())    
    
    roberta_parameters = named_parameters[:197]    
    attention_parameters = named_parameters[199:203]
    regressor_parameters = named_parameters[203:]
        
    attention_group = [params for (name, params) in attention_parameters]
    regressor_group = [params for (name, params) in regressor_parameters]

    parameters = []
    parameters.append({"params": attention_group,
                       "weight_decay": 0.001,
                      "lr": 1e-3})
    parameters.append({"params": regressor_group,
                       "weight_decay": 0.001,
                      "lr": 1e-3})

    for layer_num, (name, params) in enumerate(roberta_parameters):
        weight_decay = 0.0 if "bias" in name else 0.01

        lr = 2e-5

        if layer_num >= 69:        
            lr = 5e-5

        if layer_num >= 133:
            lr = 1e-4

        parameters.append({"params": params,
                           "weight_decay": weight_decay,
                           "lr": lr})

    return AdamW(parameters)

# %%
gc.collect()

SEED = 1000
list_val_rmse = []

kfold = KFold(n_splits=NUM_FOLDS, random_state=SEED, shuffle=True)

for fold, (train_indices, val_indices) in enumerate(kfold.split(train_df)):    
    print(f"\nFold {fold + 1}/{NUM_FOLDS}")
    model_path = f"model_{fold + 1}.pth"
        
    set_random_seed(SEED + fold)
    
    train_dataset = LitDataset(train_df.loc[train_indices])    
    val_dataset = LitDataset(train_df.loc[val_indices])    
        
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE,
                              drop_last=True, shuffle=True, num_workers=2)    
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE,
                            drop_last=False, shuffle=False, num_workers=2)    
        
    set_random_seed(SEED + fold)    
    
    model = LitModel().to(DEVICE)
    
    optimizer = create_optimizer(model)                        
    scheduler = get_cosine_schedule_with_warmup(
        optimizer,
        num_training_steps=NUM_EPOCHS * len(train_loader),
        num_warmup_steps=50)    
    
    list_val_rmse.append(train(model, model_path, train_loader,
                               val_loader, optimizer, scheduler=scheduler))

    del model
    gc.collect()
    
    print("\nPerformance estimates:")
    print(list_val_rmse)
    print("Mean:", np.array(list_val_rmse).mean())
# Out:
# Fold 1/7
# Some weights of RobertaModel were not initialized from the model checkpoint at ../input/clrp-roberta-base/clrp_roberta_base and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 16 steps took 9.86 seconds
# Epoch: 0 batch_num: 16 val_rmse: 0.9438
# New best_val_rmse: 0.9438
#
# 16 steps took 8.21 seconds
# Epoch: 0 batch_num: 32 val_rmse: 0.839
# New best_val_rmse: 0.839
#
# 16 steps took 8.28 seconds
# Epoch: 0 batch_num: 48 val_rmse: 0.9068
# Still best_val_rmse: 0.839 (from epoch 0)
#
# 16 steps took 8.24 seconds
# Epoch: 0 batch_num: 64 val_rmse: 0.8852
# Still best_val_rmse: 0.839 (from epoch 0)
#
# 16 steps took 8.25 seconds
# Epoch: 0 batch_num: 80 val_rmse: 0.7456
# New best_val_rmse: 0.7456
#
# 16 steps took 8.19 seconds
# Epoch: 0 batch_num: 96 val_rmse: 0.5917
# New best_val_rmse: 0.5917
#
# 16 steps took 8.16 seconds
# Epoch: 0 batch_num: 112 val_rmse: 0.6405
# Still best_val_rmse: 0.5917 (from epoch 0)
#
# 16 steps took 8.28 seconds
# Epoch: 0 batch_num: 128 val_rmse: 0.5252
# New best_val_rmse: 0.5252
#
# 16 steps took 8.23 seconds
# Epoch: 0 batch_num: 144 val_rmse: 0.518
# New best_val_rmse: 0.518
#
# 16 steps took 8.34 seconds
# Epoch: 1 batch_num: 9 val_rmse: 0.5495
# Still best_val_rmse: 0.518 (from epoch 0)
#
# 16 steps took 8.17 seconds
# Epoch: 1 batch_num: 25 val_rmse: 0.5263
# Still best_val_rmse: 0.518 (from epoch 0)
#
# 16 steps took 8.17 seconds
# Epoch: 1 batch_num: 41 val_rmse: 0.542
# Still best_val_rmse: 0.518 (from epoch 0)
#
# 16 steps took 8.22 seconds
# Epoch: 1 batch_num: 57 val_rmse: 0.6865
# Still best_val_rmse: 0.518 (from epoch 0)
#
# 16 steps took 8.26 seconds
# Epoch: 1 batch_num: 73 val_rmse: 0.5436
# Still best_val_rmse: 0.518 (from epoch 0)
#
# 16 steps took 8.19 seconds
# Epoch: 1 batch_num: 89 val_rmse: 0.553
# Still best_val_rmse: 0.518 (from epoch 0)
#
# 16 steps took 8.18 seconds
# Epoch: 1 batch_num: 105 val_rmse: 0.5443
# Still best_val_rmse: 0.518 (from epoch 0)
#
# 16 steps took 8.18 seconds
# Epoch: 1 batch_num: 121 val_rmse: 0.5161
# New best_val_rmse: 0.5161
#
# 16 steps took 8.26 seconds
# Epoch: 1 batch_num: 137 val_rmse: 0.4919
# New best_val_rmse: 0.4919
#
# 8 steps took 4.18 seconds
# Epoch: 1 batch_num: 145 val_rmse: 0.4968
# Still best_val_rmse: 0.4919 (from epoch 1)
#
# 8 steps took 4.2 seconds
# Epoch: 2 batch_num: 2 val_rmse: 0.5384
# Still best_val_rmse: 0.4919 (from epoch 1)
#
# 16 steps took 8.17 seconds
# Epoch: 2 batch_num: 18 val_rmse: 0.4951
# Still best_val_rmse: 0.4919 (from epoch 1)
#
# 8 steps took 4.1 seconds
# Epoch: 2 batch_num: 26 val_rmse: 0.501
# Still best_val_rmse: 0.4919 (from epoch 1)
#
# 16 steps took 8.16 seconds
# Epoch: 2 batch_num: 42 val_rmse: 0.4975
# Still best_val_rmse: 0.4919 (from epoch 1)
#
# 8 steps took 4.11 seconds
# Epoch: 2 batch_num: 50 val_rmse: 0.5015
# Still best_val_rmse: 0.4919 (from epoch 1)
#
# 16 steps took 8.23 seconds
# Epoch: 2 batch_num: 66 val_rmse: 0.5107
# Still best_val_rmse: 0.4919 (from epoch 1)
#
# 16 steps took 8.17 seconds
# Epoch: 2 batch_num: 82 val_rmse: 0.4987
# Still best_val_rmse: 0.4919 (from epoch 1)
#
# 8 steps took 4.11 seconds
# Epoch: 2 batch_num: 90 val_rmse: 0.4964
# Still best_val_rmse: 0.4919 (from epoch 1)
#
# 8 steps took 4.1 seconds
# Epoch: 2 batch_num: 98 val_rmse: 0.498
# Still best_val_rmse: 0.4919 (from epoch 1)
#
# 8 steps took 4.22 seconds
# Epoch: 2 batch_num: 106 val_rmse: 0.5004
# Still best_val_rmse: 0.4919 (from epoch 1)
#
# 16 steps took 8.19 seconds
# Epoch: 2 batch_num: 122 val_rmse: 0.4986
# Still best_val_rmse: 0.4919 (from epoch 1)
#
# 8 steps took 4.11 seconds
# Epoch: 2 batch_num: 130 val_rmse: 0.4989
# Still best_val_rmse: 0.4919 (from epoch 1)
#
# 8 steps took 4.1 seconds
# Epoch: 2 batch_num: 138 val_rmse: 0.4989
# Still best_val_rmse: 0.4919 (from epoch 1)
#
# 8 steps took 4.08 seconds
# Epoch: 2 batch_num: 146 val_rmse: 0.4988
# Still best_val_rmse: 0.4919 (from epoch 1)
#
# Performance estimates:
# [0.49190338384630194]
# Mean: 0.49190338384630194
#
# Fold 2/7
# Some weights of RobertaModel were not initialized from the model checkpoint at ../input/clrp-roberta-base/clrp_roberta_base and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 16 steps took 8.87 seconds
# Epoch: 0 batch_num: 16 val_rmse: 0.886
# New best_val_rmse: 0.886
#
# 16 steps took 8.16 seconds
# Epoch: 0 batch_num: 32 val_rmse: 0.7454
# New best_val_rmse: 0.7454
#
# 16 steps took 8.27 seconds
# Epoch: 0 batch_num: 48 val_rmse: 0.6897
# New best_val_rmse: 0.6897
#
# 16 steps took 8.2 seconds
# Epoch: 0 batch_num: 64 val_rmse: 0.7156
# Still best_val_rmse: 0.6897 (from epoch 0)
#
# 16 steps took 8.22 seconds
# Epoch: 0 batch_num: 80 val_rmse: 0.5564
# New best_val_rmse: 0.5564
#
# 16 steps took 8.31 seconds
# Epoch: 0 batch_num: 96 val_rmse: 0.5798
# Still best_val_rmse: 0.5564 (from epoch 0)
#
# 16 steps took 8.18 seconds
# Epoch: 0 batch_num: 112 val_rmse: 0.5705
# Still best_val_rmse: 0.5564 (from epoch 0)
#
# 16 steps took 8.19 seconds
# Epoch: 0 batch_num: 128 val_rmse: 0.5303
# New best_val_rmse: 0.5303
#
# 16 steps took 8.22 seconds
# Epoch: 0 batch_num: 144 val_rmse: 0.6015
# Still best_val_rmse: 0.5303 (from epoch 0)
#
# 16 steps took 8.4 seconds
# Epoch: 1 batch_num: 9 val_rmse: 0.5145
# New best_val_rmse: 0.5145
#
# 16 steps took 8.26 seconds
# Epoch: 1 batch_num: 25 val_rmse: 0.5296
# Still best_val_rmse: 0.5145 (from epoch 1)
#
# 16 steps took 8.23 seconds
# Epoch: 1 batch_num: 41 val_rmse: 0.5343
# Still best_val_rmse: 0.5145 (from epoch 1)
#
# 16 steps took 8.21 seconds
# Epoch: 1 batch_num: 57 val_rmse: 0.4978
# New best_val_rmse: 0.4978
#
# 8 steps took 4.1 seconds
# Epoch: 1 batch_num: 65 val_rmse: 0.4799
# New best_val_rmse: 0.4799
#
# 2 steps took 1.05 seconds
# Epoch: 1 batch_num: 67 val_rmse: 0.4691
# New best_val_rmse: 0.4691
#
# 1 steps took 0.522 seconds
# Epoch: 1 batch_num: 68 val_rmse: 0.4702
# Still best_val_rmse: 0.4691 (from epoch 1)
#
# 2 steps took 1.03 seconds
# Epoch: 1 batch_num: 70 val_rmse: 0.4692
# Still best_val_rmse: 0.4691 (from epoch 1)
#
# 1 steps took 0.514 seconds
# Epoch: 1 batch_num: 71 val_rmse: 0.4755
# Still best_val_rmse: 0.4691 (from epoch 1)
#
# 2 steps took 1.03 seconds
# Epoch: 1 batch_num: 73 val_rmse: 0.4956
# Still best_val_rmse: 0.4691 (from epoch 1)
#
# 8 steps took 4.09 seconds
# Epoch: 1 batch_num: 81 val_rmse: 0.4857
# Still best_val_rmse: 0.4691 (from epoch 1)
#
# 4 steps took 2.05 seconds
# Epoch: 1 batch_num: 85 val_rmse: 0.509
# Still best_val_rmse: 0.4691 (from epoch 1)
#
# 16 steps took 8.18 seconds
# Epoch: 1 batch_num: 101 val_rmse: 0.5197
# Still best_val_rmse: 0.4691 (from epoch 1)
#
# 16 steps took 8.17 seconds
# Epoch: 1 batch_num: 117 val_rmse: 0.5505
# Still best_val_rmse: 0.4691 (from epoch 1)
#
# 16 steps took 8.21 seconds
# Epoch: 1 batch_num: 133 val_rmse: 0.4951
# Still best_val_rmse: 0.4691 (from epoch 1)
#
# 8 steps took 4.12 seconds
# Epoch: 1 batch_num: 141 val_rmse: 0.4551
# New best_val_rmse: 0.4551
#
# 1 steps took 0.529 seconds
# Epoch: 1 batch_num: 142 val_rmse: 0.4653
# Still best_val_rmse: 0.4551 (from epoch 1)
#
# 1 steps took 0.516 seconds
# Epoch: 1 batch_num: 143 val_rmse: 0.4834
# Still best_val_rmse: 0.4551 (from epoch 1)
#
# 4 steps took 2.05 seconds
# Epoch: 1 batch_num: 147 val_rmse: 0.5162
# Still best_val_rmse: 0.4551 (from epoch 1)
#
# 16 steps took 8.42 seconds
# Epoch: 2 batch_num: 12 val_rmse: 0.5089
# Still best_val_rmse: 0.4551 (from epoch 1)
#
# 16 steps took 8.17 seconds
# Epoch: 2 batch_num: 28 val_rmse: 0.4559
# Still best_val_rmse: 0.4551 (from epoch 1)
#
# 1 steps took 0.538 seconds
# Epoch: 2 batch_num: 29 val_rmse: 0.4536
# New best_val_rmse: 0.4536
#
# 1 steps took 0.518 seconds
# Epoch: 2 batch_num: 30 val_rmse: 0.4525
# New best_val_rmse: 0.4525
#
# 1 steps took 0.518 seconds
# Epoch: 2 batch_num: 31 val_rmse: 0.4521
# New best_val_rmse: 0.4521
#
# 1 steps took 0.537 seconds
# Epoch: 2 batch_num: 32 val_rmse: 0.4516
# New best_val_rmse: 0.4516
#
# 1 steps took 0.519 seconds
# Epoch: 2 batch_num: 33 val_rmse: 0.4518
# Still best_val_rmse: 0.4516 (from epoch 2)
#
# 1 steps took 0.518 seconds
# Epoch: 2 batch_num: 34 val_rmse: 0.4524
# Still best_val_rmse: 0.4516 (from epoch 2)
#
# 1 steps took 0.516 seconds
# Epoch: 2 batch_num: 35 val_rmse: 0.4524
# Still best_val_rmse: 0.4516 (from epoch 2)
#
# 1 steps took 0.528 seconds
# Epoch: 2 batch_num: 36 val_rmse: 0.4516
# Still best_val_rmse: 0.4516 (from epoch 2)
#
# 1 steps took 0.515 seconds
# Epoch: 2 batch_num: 37 val_rmse: 0.4514
# New best_val_rmse: 0.4514
#
# 1 steps took 0.535 seconds
# Epoch: 2 batch_num: 38 val_rmse: 0.4522
# Still best_val_rmse: 0.4514 (from epoch 2)
#
# 1 steps took 0.512 seconds
# Epoch: 2 batch_num: 39 val_rmse: 0.4559
# Still best_val_rmse: 0.4514 (from epoch 2)
#
# 1 steps took 0.525 seconds
# Epoch: 2 batch_num: 40 val_rmse: 0.4618
# Still best_val_rmse: 0.4514 (from epoch 2)
#
# 1 steps took 0.51 seconds
# Epoch: 2 batch_num: 41 val_rmse: 0.4685
# Still best_val_rmse: 0.4514 (from epoch 2)
#
# 1 steps took 0.511 seconds
# Epoch: 2 batch_num: 42 val_rmse: 0.4722
# Still best_val_rmse: 0.4514 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 44 val_rmse: 0.4801
# Still best_val_rmse: 0.4514 (from epoch 2)
#
# 4 steps took 2.07 seconds
# Epoch: 2 batch_num: 48 val_rmse: 0.4757
# Still best_val_rmse: 0.4514 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 50 val_rmse: 0.4699
# Still best_val_rmse: 0.4514 (from epoch 2)
#
# 1 steps took 0.527 seconds
# Epoch: 2 batch_num: 51 val_rmse: 0.4659
# Still best_val_rmse: 0.4514 (from epoch 2)
#
# 1 steps took 0.527 seconds
# Epoch: 2 batch_num: 52 val_rmse: 0.4621
# Still best_val_rmse: 0.4514 (from epoch 2)
#
# 1 steps took 0.515 seconds
# Epoch: 2 batch_num: 53 val_rmse: 0.4576
# Still best_val_rmse: 0.4514 (from epoch 2)
#
# 1 steps took 0.514 seconds
# Epoch: 2 batch_num: 54 val_rmse: 0.4549
# Still best_val_rmse: 0.4514 (from epoch 2)
#
# 1 steps took 0.512 seconds
# Epoch: 2 batch_num: 55 val_rmse: 0.4534
# Still best_val_rmse: 0.4514 (from epoch 2)
#
# 1 steps took 0.511 seconds
# Epoch: 2 batch_num: 56 val_rmse: 0.453
# Still best_val_rmse: 0.4514 (from epoch 2)
#
# 1 steps took 0.51 seconds
# Epoch: 2 batch_num: 57 val_rmse: 0.4532
# Still best_val_rmse: 0.4514 (from epoch 2)
#
# 1 steps took 0.513 seconds
# Epoch: 2 batch_num: 58 val_rmse: 0.4534
# Still best_val_rmse: 0.4514 (from epoch 2)
#
# 1 steps took 0.512 seconds
# Epoch: 2 batch_num: 59 val_rmse: 0.4518
# Still best_val_rmse: 0.4514 (from epoch 2)
#
# 1 steps took 0.513 seconds
# Epoch: 2 batch_num: 60 val_rmse: 0.4499
# New best_val_rmse: 0.4499
#
# 1 steps took 0.518 seconds
# Epoch: 2 batch_num: 61 val_rmse: 0.4482
# New best_val_rmse: 0.4482
#
# 1 steps took 0.537 seconds
# Epoch: 2 batch_num: 62 val_rmse: 0.4487
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.511 seconds
# Epoch: 2 batch_num: 63 val_rmse: 0.4512
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.514 seconds
# Epoch: 2 batch_num: 64 val_rmse: 0.456
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.518 seconds
# Epoch: 2 batch_num: 65 val_rmse: 0.4624
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.517 seconds
# Epoch: 2 batch_num: 66 val_rmse: 0.4697
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.514 seconds
# Epoch: 2 batch_num: 67 val_rmse: 0.4751
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 2 steps took 1.04 seconds
# Epoch: 2 batch_num: 69 val_rmse: 0.4805
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 4 steps took 2.04 seconds
# Epoch: 2 batch_num: 73 val_rmse: 0.4599
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.511 seconds
# Epoch: 2 batch_num: 74 val_rmse: 0.4552
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.512 seconds
# Epoch: 2 batch_num: 75 val_rmse: 0.4517
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.511 seconds
# Epoch: 2 batch_num: 76 val_rmse: 0.4492
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.512 seconds
# Epoch: 2 batch_num: 77 val_rmse: 0.4484
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.531 seconds
# Epoch: 2 batch_num: 78 val_rmse: 0.4493
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.512 seconds
# Epoch: 2 batch_num: 79 val_rmse: 0.4507
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.512 seconds
# Epoch: 2 batch_num: 80 val_rmse: 0.4526
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.513 seconds
# Epoch: 2 batch_num: 81 val_rmse: 0.4536
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.514 seconds
# Epoch: 2 batch_num: 82 val_rmse: 0.4533
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.512 seconds
# Epoch: 2 batch_num: 83 val_rmse: 0.4527
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.513 seconds
# Epoch: 2 batch_num: 84 val_rmse: 0.4518
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.513 seconds
# Epoch: 2 batch_num: 85 val_rmse: 0.4519
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.512 seconds
# Epoch: 2 batch_num: 86 val_rmse: 0.4523
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.512 seconds
# Epoch: 2 batch_num: 87 val_rmse: 0.4535
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.513 seconds
# Epoch: 2 batch_num: 88 val_rmse: 0.4549
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.587 seconds
# Epoch: 2 batch_num: 89 val_rmse: 0.4573
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.514 seconds
# Epoch: 2 batch_num: 90 val_rmse: 0.4596
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.516 seconds
# Epoch: 2 batch_num: 91 val_rmse: 0.4623
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.512 seconds
# Epoch: 2 batch_num: 92 val_rmse: 0.4649
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.511 seconds
# Epoch: 2 batch_num: 93 val_rmse: 0.467
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.511 seconds
# Epoch: 2 batch_num: 94 val_rmse: 0.4683
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.512 seconds
# Epoch: 2 batch_num: 95 val_rmse: 0.4681
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.511 seconds
# Epoch: 2 batch_num: 96 val_rmse: 0.4668
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.511 seconds
# Epoch: 2 batch_num: 97 val_rmse: 0.4648
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.51 seconds
# Epoch: 2 batch_num: 98 val_rmse: 0.4631
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.511 seconds
# Epoch: 2 batch_num: 99 val_rmse: 0.4613
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.525 seconds
# Epoch: 2 batch_num: 100 val_rmse: 0.4598
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.513 seconds
# Epoch: 2 batch_num: 101 val_rmse: 0.4588
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.537 seconds
# Epoch: 2 batch_num: 102 val_rmse: 0.4576
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.529 seconds
# Epoch: 2 batch_num: 103 val_rmse: 0.4571
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.515 seconds
# Epoch: 2 batch_num: 104 val_rmse: 0.4565
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.512 seconds
# Epoch: 2 batch_num: 105 val_rmse: 0.4562
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.514 seconds
# Epoch: 2 batch_num: 106 val_rmse: 0.4559
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.513 seconds
# Epoch: 2 batch_num: 107 val_rmse: 0.4551
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.512 seconds
# Epoch: 2 batch_num: 108 val_rmse: 0.4548
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.511 seconds
# Epoch: 2 batch_num: 109 val_rmse: 0.4542
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.517 seconds
# Epoch: 2 batch_num: 110 val_rmse: 0.4534
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.513 seconds
# Epoch: 2 batch_num: 111 val_rmse: 0.4528
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.51 seconds
# Epoch: 2 batch_num: 112 val_rmse: 0.4521
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.523 seconds
# Epoch: 2 batch_num: 113 val_rmse: 0.4519
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.511 seconds
# Epoch: 2 batch_num: 114 val_rmse: 0.4517
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.515 seconds
# Epoch: 2 batch_num: 115 val_rmse: 0.4514
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.511 seconds
# Epoch: 2 batch_num: 116 val_rmse: 0.4511
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.513 seconds
# Epoch: 2 batch_num: 117 val_rmse: 0.4508
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.514 seconds
# Epoch: 2 batch_num: 118 val_rmse: 0.4506
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.51 seconds
# Epoch: 2 batch_num: 119 val_rmse: 0.4505
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.51 seconds
# Epoch: 2 batch_num: 120 val_rmse: 0.4502
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.51 seconds
# Epoch: 2 batch_num: 121 val_rmse: 0.45
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.51 seconds
# Epoch: 2 batch_num: 122 val_rmse: 0.4499
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.511 seconds
# Epoch: 2 batch_num: 123 val_rmse: 0.4497
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.544 seconds
# Epoch: 2 batch_num: 124 val_rmse: 0.4496
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.511 seconds
# Epoch: 2 batch_num: 125 val_rmse: 0.4494
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.51 seconds
# Epoch: 2 batch_num: 126 val_rmse: 0.4493
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.512 seconds
# Epoch: 2 batch_num: 127 val_rmse: 0.4492
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.513 seconds
# Epoch: 2 batch_num: 128 val_rmse: 0.4492
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.516 seconds
# Epoch: 2 batch_num: 129 val_rmse: 0.4492
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.512 seconds
# Epoch: 2 batch_num: 130 val_rmse: 0.4492
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.512 seconds
# Epoch: 2 batch_num: 131 val_rmse: 0.4491
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.513 seconds
# Epoch: 2 batch_num: 132 val_rmse: 0.4491
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.511 seconds
# Epoch: 2 batch_num: 133 val_rmse: 0.4491
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.514 seconds
# Epoch: 2 batch_num: 134 val_rmse: 0.4491
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.512 seconds
# Epoch: 2 batch_num: 135 val_rmse: 0.4491
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.511 seconds
# Epoch: 2 batch_num: 136 val_rmse: 0.4491
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.535 seconds
# Epoch: 2 batch_num: 137 val_rmse: 0.4491
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.512 seconds
# Epoch: 2 batch_num: 138 val_rmse: 0.4491
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.51 seconds
# Epoch: 2 batch_num: 139 val_rmse: 0.4491
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.511 seconds
# Epoch: 2 batch_num: 140 val_rmse: 0.4491
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.515 seconds
# Epoch: 2 batch_num: 141 val_rmse: 0.4491
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.514 seconds
# Epoch: 2 batch_num: 142 val_rmse: 0.4491
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.518 seconds
# Epoch: 2 batch_num: 143 val_rmse: 0.4491
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.515 seconds
# Epoch: 2 batch_num: 144 val_rmse: 0.4491
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.51 seconds
# Epoch: 2 batch_num: 145 val_rmse: 0.4491
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.511 seconds
# Epoch: 2 batch_num: 146 val_rmse: 0.4491
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.51 seconds
# Epoch: 2 batch_num: 147 val_rmse: 0.4491
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.518 seconds
# Epoch: 2 batch_num: 148 val_rmse: 0.4491
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.51 seconds
# Epoch: 2 batch_num: 149 val_rmse: 0.4491
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# 1 steps took 0.53 seconds
# Epoch: 2 batch_num: 150 val_rmse: 0.4491
# Still best_val_rmse: 0.4482 (from epoch 2)
#
# Performance estimates:
# [0.49190338384630194, 0.4481513582344671]
# Mean: 0.4700273710403845
#
# Fold 3/7
# Some weights of RobertaModel were not initialized from the model checkpoint at ../input/clrp-roberta-base/clrp_roberta_base and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 16 steps took 8.86 seconds
# Epoch: 0 batch_num: 16 val_rmse: 0.95
# New best_val_rmse: 0.95
#
# 16 steps took 8.25 seconds
# Epoch: 0 batch_num: 32 val_rmse: 0.7005
# New best_val_rmse: 0.7005
#
# 16 steps took 8.2 seconds
# Epoch: 0 batch_num: 48 val_rmse: 0.7381
# Still best_val_rmse: 0.7005 (from epoch 0)
#
# 16 steps took 8.21 seconds
# Epoch: 0 batch_num: 64 val_rmse: 0.5689
# New best_val_rmse: 0.5689
#
# 16 steps took 8.22 seconds
# Epoch: 0 batch_num: 80 val_rmse: 0.6624
# Still best_val_rmse: 0.5689 (from epoch 0)
#
# 16 steps took 8.19 seconds
# Epoch: 0 batch_num: 96 val_rmse: 0.5728
# Still best_val_rmse: 0.5689 (from epoch 0)
#
# 16 steps took 8.17 seconds
# Epoch: 0 batch_num: 112 val_rmse: 0.5344
# New best_val_rmse: 0.5344
#
# 16 steps took 8.2 seconds
# Epoch: 0 batch_num: 128 val_rmse: 0.5406
# Still best_val_rmse: 0.5344 (from epoch 0)
#
# 16 steps took 8.24 seconds
# Epoch: 0 batch_num: 144 val_rmse: 0.5903
# Still best_val_rmse: 0.5344 (from epoch 0)
#
# 16 steps took 8.37 seconds
# Epoch: 1 batch_num: 9 val_rmse: 0.5018
# New best_val_rmse: 0.5018
#
# 16 steps took 8.17 seconds
# Epoch: 1 batch_num: 25 val_rmse: 0.5592
# Still best_val_rmse: 0.5018 (from epoch 1)
#
# 16 steps took 8.2 seconds
# Epoch: 1 batch_num: 41 val_rmse: 0.503
# Still best_val_rmse: 0.5018 (from epoch 1)
#
# 16 steps took 8.18 seconds
# Epoch: 1 batch_num: 57 val_rmse: 0.5277
# Still best_val_rmse: 0.5018 (from epoch 1)
#
# 16 steps took 8.26 seconds
# Epoch: 1 batch_num: 73 val_rmse: 0.5234
# Still best_val_rmse: 0.5018 (from epoch 1)
#
# 16 steps took 8.24 seconds
# Epoch: 1 batch_num: 89 val_rmse: 0.5103
# Still best_val_rmse: 0.5018 (from epoch 1)
#
# 16 steps took 8.19 seconds
# Epoch: 1 batch_num: 105 val_rmse: 0.4996
# New best_val_rmse: 0.4996
#
# 8 steps took 4.11 seconds
# Epoch: 1 batch_num: 113 val_rmse: 0.4862
# New best_val_rmse: 0.4862
#
# 4 steps took 2.05 seconds
# Epoch: 1 batch_num: 117 val_rmse: 0.4798
# New best_val_rmse: 0.4798
#
# 2 steps took 1.07 seconds
# Epoch: 1 batch_num: 119 val_rmse: 0.4799
# Still best_val_rmse: 0.4798 (from epoch 1)
#
# 2 steps took 1.03 seconds
# Epoch: 1 batch_num: 121 val_rmse: 0.4826
# Still best_val_rmse: 0.4798 (from epoch 1)
#
# 4 steps took 2.07 seconds
# Epoch: 1 batch_num: 125 val_rmse: 0.4841
# Still best_val_rmse: 0.4798 (from epoch 1)
#
# 4 steps took 2.05 seconds
# Epoch: 1 batch_num: 129 val_rmse: 0.4894
# Still best_val_rmse: 0.4798 (from epoch 1)
#
# 4 steps took 2.05 seconds
# Epoch: 1 batch_num: 133 val_rmse: 0.4995
# Still best_val_rmse: 0.4798 (from epoch 1)
#
# 8 steps took 4.1 seconds
# Epoch: 1 batch_num: 141 val_rmse: 0.5027
# Still best_val_rmse: 0.4798 (from epoch 1)
#
# 16 steps took 8.36 seconds
# Epoch: 2 batch_num: 6 val_rmse: 0.4962
# Still best_val_rmse: 0.4798 (from epoch 1)
#
# 8 steps took 4.11 seconds
# Epoch: 2 batch_num: 14 val_rmse: 0.4821
# Still best_val_rmse: 0.4798 (from epoch 1)
#
# 4 steps took 2.04 seconds
# Epoch: 2 batch_num: 18 val_rmse: 0.4649
# New best_val_rmse: 0.4649
#
# 1 steps took 0.526 seconds
# Epoch: 2 batch_num: 19 val_rmse: 0.4652
# Still best_val_rmse: 0.4649 (from epoch 2)
#
# 1 steps took 0.514 seconds
# Epoch: 2 batch_num: 20 val_rmse: 0.4676
# Still best_val_rmse: 0.4649 (from epoch 2)
#
# 1 steps took 0.513 seconds
# Epoch: 2 batch_num: 21 val_rmse: 0.4703
# Still best_val_rmse: 0.4649 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 23 val_rmse: 0.4692
# Still best_val_rmse: 0.4649 (from epoch 2)
#
# 1 steps took 0.513 seconds
# Epoch: 2 batch_num: 24 val_rmse: 0.4673
# Still best_val_rmse: 0.4649 (from epoch 2)
#
# 1 steps took 0.512 seconds
# Epoch: 2 batch_num: 25 val_rmse: 0.4691
# Still best_val_rmse: 0.4649 (from epoch 2)
#
# 1 steps took 0.512 seconds
# Epoch: 2 batch_num: 26 val_rmse: 0.4756
# Still best_val_rmse: 0.4649 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 28 val_rmse: 0.4958
# Still best_val_rmse: 0.4649 (from epoch 2)
#
# 8 steps took 4.18 seconds
# Epoch: 2 batch_num: 36 val_rmse: 0.4645
# New best_val_rmse: 0.4645
#
# 1 steps took 0.55 seconds
# Epoch: 2 batch_num: 37 val_rmse: 0.4647
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.51 seconds
# Epoch: 2 batch_num: 38 val_rmse: 0.4647
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.512 seconds
# Epoch: 2 batch_num: 39 val_rmse: 0.4645
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.511 seconds
# Epoch: 2 batch_num: 40 val_rmse: 0.4647
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.512 seconds
# Epoch: 2 batch_num: 41 val_rmse: 0.4668
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.529 seconds
# Epoch: 2 batch_num: 42 val_rmse: 0.4708
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 44 val_rmse: 0.4809
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 4 steps took 2.04 seconds
# Epoch: 2 batch_num: 48 val_rmse: 0.4805
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 4 steps took 2.04 seconds
# Epoch: 2 batch_num: 52 val_rmse: 0.4703
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 54 val_rmse: 0.4671
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.514 seconds
# Epoch: 2 batch_num: 55 val_rmse: 0.4667
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.513 seconds
# Epoch: 2 batch_num: 56 val_rmse: 0.4668
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.511 seconds
# Epoch: 2 batch_num: 57 val_rmse: 0.4677
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.511 seconds
# Epoch: 2 batch_num: 58 val_rmse: 0.469
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.51 seconds
# Epoch: 2 batch_num: 59 val_rmse: 0.4696
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.511 seconds
# Epoch: 2 batch_num: 60 val_rmse: 0.4691
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.511 seconds
# Epoch: 2 batch_num: 61 val_rmse: 0.4684
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.513 seconds
# Epoch: 2 batch_num: 62 val_rmse: 0.4688
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.511 seconds
# Epoch: 2 batch_num: 63 val_rmse: 0.4721
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 65 val_rmse: 0.4831
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 4 steps took 2.04 seconds
# Epoch: 2 batch_num: 69 val_rmse: 0.4883
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 4 steps took 2.05 seconds
# Epoch: 2 batch_num: 73 val_rmse: 0.4825
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 4 steps took 2.05 seconds
# Epoch: 2 batch_num: 77 val_rmse: 0.4684
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.517 seconds
# Epoch: 2 batch_num: 78 val_rmse: 0.468
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.516 seconds
# Epoch: 2 batch_num: 79 val_rmse: 0.4679
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.514 seconds
# Epoch: 2 batch_num: 80 val_rmse: 0.4678
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.512 seconds
# Epoch: 2 batch_num: 81 val_rmse: 0.4678
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.511 seconds
# Epoch: 2 batch_num: 82 val_rmse: 0.4678
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.525 seconds
# Epoch: 2 batch_num: 83 val_rmse: 0.4679
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.512 seconds
# Epoch: 2 batch_num: 84 val_rmse: 0.4679
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.51 seconds
# Epoch: 2 batch_num: 85 val_rmse: 0.468
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.522 seconds
# Epoch: 2 batch_num: 86 val_rmse: 0.4681
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.511 seconds
# Epoch: 2 batch_num: 87 val_rmse: 0.4681
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.511 seconds
# Epoch: 2 batch_num: 88 val_rmse: 0.4682
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.517 seconds
# Epoch: 2 batch_num: 89 val_rmse: 0.4683
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.511 seconds
# Epoch: 2 batch_num: 90 val_rmse: 0.4686
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.515 seconds
# Epoch: 2 batch_num: 91 val_rmse: 0.4688
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.513 seconds
# Epoch: 2 batch_num: 92 val_rmse: 0.4691
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.513 seconds
# Epoch: 2 batch_num: 93 val_rmse: 0.4694
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.524 seconds
# Epoch: 2 batch_num: 94 val_rmse: 0.4696
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.512 seconds
# Epoch: 2 batch_num: 95 val_rmse: 0.47
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.511 seconds
# Epoch: 2 batch_num: 96 val_rmse: 0.4703
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 98 val_rmse: 0.4715
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 100 val_rmse: 0.4718
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 102 val_rmse: 0.4722
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 104 val_rmse: 0.4718
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 2 steps took 1.07 seconds
# Epoch: 2 batch_num: 106 val_rmse: 0.4711
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 108 val_rmse: 0.4704
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 110 val_rmse: 0.4703
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 112 val_rmse: 0.4703
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 114 val_rmse: 0.4706
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 116 val_rmse: 0.4708
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 118 val_rmse: 0.4708
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 120 val_rmse: 0.4707
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 122 val_rmse: 0.4703
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 124 val_rmse: 0.4703
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 126 val_rmse: 0.47
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 128 val_rmse: 0.4698
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.517 seconds
# Epoch: 2 batch_num: 129 val_rmse: 0.4699
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.512 seconds
# Epoch: 2 batch_num: 130 val_rmse: 0.4699
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.524 seconds
# Epoch: 2 batch_num: 131 val_rmse: 0.47
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.514 seconds
# Epoch: 2 batch_num: 132 val_rmse: 0.47
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.525 seconds
# Epoch: 2 batch_num: 133 val_rmse: 0.47
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 135 val_rmse: 0.47
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 2 steps took 1.04 seconds
# Epoch: 2 batch_num: 137 val_rmse: 0.4701
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 139 val_rmse: 0.47
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 2 steps took 1.04 seconds
# Epoch: 2 batch_num: 141 val_rmse: 0.47
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.516 seconds
# Epoch: 2 batch_num: 142 val_rmse: 0.4699
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.513 seconds
# Epoch: 2 batch_num: 143 val_rmse: 0.4699
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.514 seconds
# Epoch: 2 batch_num: 144 val_rmse: 0.4699
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.514 seconds
# Epoch: 2 batch_num: 145 val_rmse: 0.4699
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.513 seconds
# Epoch: 2 batch_num: 146 val_rmse: 0.4699
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.511 seconds
# Epoch: 2 batch_num: 147 val_rmse: 0.4699
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.511 seconds
# Epoch: 2 batch_num: 148 val_rmse: 0.4699
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.51 seconds
# Epoch: 2 batch_num: 149 val_rmse: 0.4699
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.511 seconds
# Epoch: 2 batch_num: 150 val_rmse: 0.4699
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# Performance estimates:
# [0.49190338384630194, 0.4481513582344671, 0.46446157179868375]
# Mean: 0.46817210462648423
#
# Fold 4/7
# Some weights of RobertaModel were not initialized from the model checkpoint at ../input/clrp-roberta-base/clrp_roberta_base and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 16 steps took 8.86 seconds
# Epoch: 0 batch_num: 16 val_rmse: 0.9628
# New best_val_rmse: 0.9628
#
# 16 steps took 8.28 seconds
# Epoch: 0 batch_num: 32 val_rmse: 0.8627
# New best_val_rmse: 0.8627
#
# 16 steps took 8.23 seconds
# Epoch: 0 batch_num: 48 val_rmse: 0.6337
# New best_val_rmse: 0.6337
#
# 16 steps took 8.22 seconds
# Epoch: 0 batch_num: 64 val_rmse: 0.6111
# New best_val_rmse: 0.6111
#
# 16 steps took 8.23 seconds
# Epoch: 0 batch_num: 80 val_rmse: 0.5481
# New best_val_rmse: 0.5481
#
# 16 steps took 8.24 seconds
# Epoch: 0 batch_num: 96 val_rmse: 0.5415
# New best_val_rmse: 0.5415
#
# 16 steps took 8.27 seconds
# Epoch: 0 batch_num: 112 val_rmse: 0.6224
# Still best_val_rmse: 0.5415 (from epoch 0)
#
# 16 steps took 8.23 seconds
# Epoch: 0 batch_num: 128 val_rmse: 0.5888
# Still best_val_rmse: 0.5415 (from epoch 0)
#
# 16 steps took 8.17 seconds
# Epoch: 0 batch_num: 144 val_rmse: 0.5293
# New best_val_rmse: 0.5293
#
# 16 steps took 8.38 seconds
# Epoch: 1 batch_num: 9 val_rmse: 0.5366
# Still best_val_rmse: 0.5293 (from epoch 0)
#
# 16 steps took 8.26 seconds
# Epoch: 1 batch_num: 25 val_rmse: 0.6054
# Still best_val_rmse: 0.5293 (from epoch 0)
#
# 16 steps took 8.24 seconds
# Epoch: 1 batch_num: 41 val_rmse: 0.5144
# New best_val_rmse: 0.5144
#
# 16 steps took 8.23 seconds
# Epoch: 1 batch_num: 57 val_rmse: 0.5013
# New best_val_rmse: 0.5013
#
# 16 steps took 8.2 seconds
# Epoch: 1 batch_num: 73 val_rmse: 0.5551
# Still best_val_rmse: 0.5013 (from epoch 1)
#
# 16 steps took 8.2 seconds
# Epoch: 1 batch_num: 89 val_rmse: 0.5076
# Still best_val_rmse: 0.5013 (from epoch 1)
#
# 16 steps took 8.24 seconds
# Epoch: 1 batch_num: 105 val_rmse: 0.5013
# Still best_val_rmse: 0.5013 (from epoch 1)
#
# 16 steps took 8.23 seconds
# Epoch: 1 batch_num: 121 val_rmse: 0.4967
# New best_val_rmse: 0.4967
#
# 8 steps took 4.19 seconds
# Epoch: 1 batch_num: 129 val_rmse: 0.5067
# Still best_val_rmse: 0.4967 (from epoch 1)
#
# 16 steps took 8.22 seconds
# Epoch: 1 batch_num: 145 val_rmse: 0.4958
# New best_val_rmse: 0.4958
#
# 8 steps took 4.26 seconds
# Epoch: 2 batch_num: 2 val_rmse: 0.4925
# New best_val_rmse: 0.4925
#
# 8 steps took 4.16 seconds
# Epoch: 2 batch_num: 10 val_rmse: 0.4902
# New best_val_rmse: 0.4902
#
# 8 steps took 4.09 seconds
# Epoch: 2 batch_num: 18 val_rmse: 0.4862
# New best_val_rmse: 0.4862
#
# 4 steps took 2.05 seconds
# Epoch: 2 batch_num: 22 val_rmse: 0.487
# Still best_val_rmse: 0.4862 (from epoch 2)
#
# 4 steps took 2.04 seconds
# Epoch: 2 batch_num: 26 val_rmse: 0.4795
# New best_val_rmse: 0.4795
#
# 2 steps took 1.04 seconds
# Epoch: 2 batch_num: 28 val_rmse: 0.4783
# New best_val_rmse: 0.4783
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 30 val_rmse: 0.4768
# New best_val_rmse: 0.4768
#
# 2 steps took 1.04 seconds
# Epoch: 2 batch_num: 32 val_rmse: 0.4789
# Still best_val_rmse: 0.4768 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 34 val_rmse: 0.4845
# Still best_val_rmse: 0.4768 (from epoch 2)
#
# 4 steps took 2.07 seconds
# Epoch: 2 batch_num: 38 val_rmse: 0.4841
# Still best_val_rmse: 0.4768 (from epoch 2)
#
# 4 steps took 2.06 seconds
# Epoch: 2 batch_num: 42 val_rmse: 0.4816
# Still best_val_rmse: 0.4768 (from epoch 2)
#
# 4 steps took 2.04 seconds
# Epoch: 2 batch_num: 46 val_rmse: 0.4733
# New best_val_rmse: 0.4733
#
# 2 steps took 1.04 seconds
# Epoch: 2 batch_num: 48 val_rmse: 0.4759
# Still best_val_rmse: 0.4733 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 50 val_rmse: 0.4794
# Still best_val_rmse: 0.4733 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 52 val_rmse: 0.4763
# Still best_val_rmse: 0.4733 (from epoch 2)
#
# 2 steps took 1.05 seconds
# Epoch: 2 batch_num: 54 val_rmse: 0.4735
# Still best_val_rmse: 0.4733 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 56 val_rmse: 0.4743
# Still best_val_rmse: 0.4733 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 58 val_rmse: 0.4776
# Still best_val_rmse: 0.4733 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 60 val_rmse: 0.4812
# Still best_val_rmse: 0.4733 (from epoch 2)
#
# 4 steps took 2.06 seconds
# Epoch: 2 batch_num: 64 val_rmse: 0.4778
# Still best_val_rmse: 0.4733 (from epoch 2)
#
# 2 steps took 1.04 seconds
# Epoch: 2 batch_num: 66 val_rmse: 0.4731
# New best_val_rmse: 0.4731
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 68 val_rmse: 0.473
# New best_val_rmse: 0.473
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 70 val_rmse: 0.4731
# Still best_val_rmse: 0.473 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 72 val_rmse: 0.4729
# New best_val_rmse: 0.4729
#
# 2 steps took 1.04 seconds
# Epoch: 2 batch_num: 74 val_rmse: 0.4728
# New best_val_rmse: 0.4728
#
# 2 steps took 1.04 seconds
# Epoch: 2 batch_num: 76 val_rmse: 0.473
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.05 seconds
# Epoch: 2 batch_num: 78 val_rmse: 0.4734
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 80 val_rmse: 0.4736
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 82 val_rmse: 0.474
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 84 val_rmse: 0.474
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 86 val_rmse: 0.4745
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 88 val_rmse: 0.4754
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.04 seconds
# Epoch: 2 batch_num: 90 val_rmse: 0.4769
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 92 val_rmse: 0.4776
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 94 val_rmse: 0.4776
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 96 val_rmse: 0.4781
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 98 val_rmse: 0.4784
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 100 val_rmse: 0.4785
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.04 seconds
# Epoch: 2 batch_num: 102 val_rmse: 0.4774
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 104 val_rmse: 0.4764
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 106 val_rmse: 0.4761
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 108 val_rmse: 0.4759
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 110 val_rmse: 0.4757
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 112 val_rmse: 0.4756
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.05 seconds
# Epoch: 2 batch_num: 114 val_rmse: 0.4754
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 116 val_rmse: 0.4752
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 118 val_rmse: 0.475
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 120 val_rmse: 0.4747
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 122 val_rmse: 0.4746
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 124 val_rmse: 0.4745
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.04 seconds
# Epoch: 2 batch_num: 126 val_rmse: 0.4745
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 128 val_rmse: 0.4744
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 130 val_rmse: 0.4744
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 132 val_rmse: 0.4743
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 134 val_rmse: 0.4743
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 136 val_rmse: 0.4743
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 138 val_rmse: 0.4743
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 140 val_rmse: 0.4742
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 142 val_rmse: 0.4742
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 144 val_rmse: 0.4742
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 146 val_rmse: 0.4742
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 148 val_rmse: 0.4742
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 1.04 seconds
# Epoch: 2 batch_num: 150 val_rmse: 0.4742
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# Performance estimates:
# [0.49190338384630194, 0.4481513582344671, 0.46446157179868375, 0.47284795280892244]
# Mean: 0.4693410666720938
#
# Fold 5/7
# Some weights of RobertaModel were not initialized from the model checkpoint at ../input/clrp-roberta-base/clrp_roberta_base and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 16 steps took 8.84 seconds
# Epoch: 0 batch_num: 16 val_rmse: 0.9256
# New best_val_rmse: 0.9256
#
# 16 steps took 8.19 seconds
# Epoch: 0 batch_num: 32 val_rmse: 0.7616
# New best_val_rmse: 0.7616
#
# 16 steps took 8.25 seconds
# Epoch: 0 batch_num: 48 val_rmse: 0.7078
# New best_val_rmse: 0.7078
#
# 16 steps took 8.25 seconds
# Epoch: 0 batch_num: 64 val_rmse: 0.6713
# New best_val_rmse: 0.6713
#
# 16 steps took 8.2 seconds
# Epoch: 0 batch_num: 80 val_rmse: 0.7208
# Still best_val_rmse: 0.6713 (from epoch 0)
#
# 16 steps took 8.18 seconds
# Epoch: 0 batch_num: 96 val_rmse: 0.6294
# New best_val_rmse: 0.6294
#
# 16 steps took 8.28 seconds
# Epoch: 0 batch_num: 112 val_rmse: 0.5973
# New best_val_rmse: 0.5973
#
# 16 steps took 8.22 seconds
# Epoch: 0 batch_num: 128 val_rmse: 0.6289
# Still best_val_rmse: 0.5973 (from epoch 0)
#
# 16 steps took 8.17 seconds
# Epoch: 0 batch_num: 144 val_rmse: 0.5471
# New best_val_rmse: 0.5471
#
# 16 steps took 8.35 seconds
# Epoch: 1 batch_num: 9 val_rmse: 0.6255
# Still best_val_rmse: 0.5471 (from epoch 0)
#
# 16 steps took 8.18 seconds
# Epoch: 1 batch_num: 25 val_rmse: 0.6096
# Still best_val_rmse: 0.5471 (from epoch 0)
#
# 16 steps took 8.21 seconds
# Epoch: 1 batch_num: 41 val_rmse: 0.5803
# Still best_val_rmse: 0.5471 (from epoch 0)
#
# 16 steps took 8.23 seconds
# Epoch: 1 batch_num: 57 val_rmse: 0.5642
# Still best_val_rmse: 0.5471 (from epoch 0)
#
# 16 steps took 8.22 seconds
# Epoch: 1 batch_num: 73 val_rmse: 0.5617
# Still best_val_rmse: 0.5471 (from epoch 0)
#
# 16 steps took 8.19 seconds
# Epoch: 1 batch_num: 89 val_rmse: 0.5195
# New best_val_rmse: 0.5195
#
# 16 steps took 8.22 seconds
# Epoch: 1 batch_num: 105 val_rmse: 0.5173
# New best_val_rmse: 0.5173
#
# 16 steps took 8.25 seconds
# Epoch: 1 batch_num: 121 val_rmse: 0.5109
# New best_val_rmse: 0.5109
#
# 16 steps took 8.28 seconds
# Epoch: 1 batch_num: 137 val_rmse: 0.5378
# Still best_val_rmse: 0.5109 (from epoch 1)
#
# 16 steps took 8.37 seconds
# Epoch: 2 batch_num: 2 val_rmse: 0.5219
# Still best_val_rmse: 0.5109 (from epoch 1)
#
# 16 steps took 8.24 seconds
# Epoch: 2 batch_num: 18 val_rmse: 0.5022
# New best_val_rmse: 0.5022
#
# 16 steps took 8.22 seconds
# Epoch: 2 batch_num: 34 val_rmse: 0.5116
# Still best_val_rmse: 0.5022 (from epoch 2)
#
# 16 steps took 8.19 seconds
# Epoch: 2 batch_num: 50 val_rmse: 0.5005
# New best_val_rmse: 0.5005
#
# 16 steps took 8.21 seconds
# Epoch: 2 batch_num: 66 val_rmse: 0.5164
# Still best_val_rmse: 0.5005 (from epoch 2)
#
# 16 steps took 8.22 seconds
# Epoch: 2 batch_num: 82 val_rmse: 0.5091
# Still best_val_rmse: 0.5005 (from epoch 2)
#
# 16 steps took 8.23 seconds
# Epoch: 2 batch_num: 98 val_rmse: 0.5029
# Still best_val_rmse: 0.5005 (from epoch 2)
#
# 16 steps took 8.19 seconds
# Epoch: 2 batch_num: 114 val_rmse: 0.5083
# Still best_val_rmse: 0.5005 (from epoch 2)
#
# 16 steps took 8.18 seconds
# Epoch: 2 batch_num: 130 val_rmse: 0.5087
# Still best_val_rmse: 0.5005 (from epoch 2)
#
# 16 steps took 8.17 seconds
# Epoch: 2 batch_num: 146 val_rmse: 0.5058
# Still best_val_rmse: 0.5005 (from epoch 2)
#
# Performance estimates:
# [0.49190338384630194, 0.4481513582344671, 0.46446157179868375, 0.47284795280892244, 0.5004512219628822]
# Mean: 0.47556309773025146
#
# Fold 6/7
# Some weights of RobertaModel were not initialized from the model checkpoint at ../input/clrp-roberta-base/clrp_roberta_base and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 16 steps took 8.9 seconds
# Epoch: 0 batch_num: 16 val_rmse: 0.9189
# New best_val_rmse: 0.9189
#
# 16 steps took 8.2 seconds
# Epoch: 0 batch_num: 32 val_rmse: 1.017
# Still best_val_rmse: 0.9189 (from epoch 0)
#
# 16 steps took 8.17 seconds
# Epoch: 0 batch_num: 48 val_rmse: 0.6595
# New best_val_rmse: 0.6595
#
# 16 steps took 8.21 seconds
# Epoch: 0 batch_num: 64 val_rmse: 0.6287
# New best_val_rmse: 0.6287
#
# 16 steps took 8.27 seconds
# Epoch: 0 batch_num: 80 val_rmse: 0.5726
# New best_val_rmse: 0.5726
#
# 16 steps took 8.23 seconds
# Epoch: 0 batch_num: 96 val_rmse: 0.6137
# Still best_val_rmse: 0.5726 (from epoch 0)
#
# 16 steps took 8.18 seconds
# Epoch: 0 batch_num: 112 val_rmse: 0.5699
# New best_val_rmse: 0.5699
#
# 16 steps took 8.2 seconds
# Epoch: 0 batch_num: 128 val_rmse: 0.5979
# Still best_val_rmse: 0.5699 (from epoch 0)
#
# 16 steps took 8.19 seconds
# Epoch: 0 batch_num: 144 val_rmse: 0.5506
# New best_val_rmse: 0.5506
#
# 16 steps took 8.42 seconds
# Epoch: 1 batch_num: 9 val_rmse: 0.4975
# New best_val_rmse: 0.4975
#
# 8 steps took 4.14 seconds
# Epoch: 1 batch_num: 17 val_rmse: 0.5037
# Still best_val_rmse: 0.4975 (from epoch 1)
#
# 16 steps took 8.18 seconds
# Epoch: 1 batch_num: 33 val_rmse: 0.5016
# Still best_val_rmse: 0.4975 (from epoch 1)
#
# 16 steps took 8.23 seconds
# Epoch: 1 batch_num: 49 val_rmse: 0.4855
# New best_val_rmse: 0.4855
#
# 4 steps took 2.07 seconds
# Epoch: 1 batch_num: 53 val_rmse: 0.5567
# Still best_val_rmse: 0.4855 (from epoch 1)
#
# 16 steps took 8.19 seconds
# Epoch: 1 batch_num: 69 val_rmse: 0.5039
# Still best_val_rmse: 0.4855 (from epoch 1)
#
# 16 steps took 8.2 seconds
# Epoch: 1 batch_num: 85 val_rmse: 0.4937
# Still best_val_rmse: 0.4855 (from epoch 1)
#
# 8 steps took 4.08 seconds
# Epoch: 1 batch_num: 93 val_rmse: 0.5138
# Still best_val_rmse: 0.4855 (from epoch 1)
#
# 16 steps took 8.2 seconds
# Epoch: 1 batch_num: 109 val_rmse: 0.516
# Still best_val_rmse: 0.4855 (from epoch 1)
#
# 16 steps took 8.22 seconds
# Epoch: 1 batch_num: 125 val_rmse: 0.4911
# Still best_val_rmse: 0.4855 (from epoch 1)
#
# 8 steps took 4.22 seconds
# Epoch: 1 batch_num: 133 val_rmse: 0.4992
# Still best_val_rmse: 0.4855 (from epoch 1)
#
# 8 steps took 4.09 seconds
# Epoch: 1 batch_num: 141 val_rmse: 0.5041
# Still best_val_rmse: 0.4855 (from epoch 1)
#
# 16 steps took 8.36 seconds
# Epoch: 2 batch_num: 6 val_rmse: 0.5267
# Still best_val_rmse: 0.4855 (from epoch 1)
#
# 16 steps took 8.21 seconds
# Epoch: 2 batch_num: 22 val_rmse: 0.4881
# Still best_val_rmse: 0.4855 (from epoch 1)
#
# 4 steps took 2.04 seconds
# Epoch: 2 batch_num: 26 val_rmse: 0.4729
# New best_val_rmse: 0.4729
#
# 2 steps took 1.04 seconds
# Epoch: 2 batch_num: 28 val_rmse: 0.4738
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 30 val_rmse: 0.4752
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 32 val_rmse: 0.4819
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 4 steps took 2.06 seconds
# Epoch: 2 batch_num: 36 val_rmse: 0.4936
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 8 steps took 4.09 seconds
# Epoch: 2 batch_num: 44 val_rmse: 0.4791
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.04 seconds
# Epoch: 2 batch_num: 46 val_rmse: 0.4758
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 48 val_rmse: 0.4778
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 50 val_rmse: 0.4776
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.04 seconds
# Epoch: 2 batch_num: 52 val_rmse: 0.4793
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 54 val_rmse: 0.4841
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 4 steps took 2.04 seconds
# Epoch: 2 batch_num: 58 val_rmse: 0.4771
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.05 seconds
# Epoch: 2 batch_num: 60 val_rmse: 0.4747
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 62 val_rmse: 0.4729
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 64 val_rmse: 0.4731
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 66 val_rmse: 0.4749
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 68 val_rmse: 0.476
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 70 val_rmse: 0.4744
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.04 seconds
# Epoch: 2 batch_num: 72 val_rmse: 0.4739
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 74 val_rmse: 0.4757
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 76 val_rmse: 0.4798
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 78 val_rmse: 0.4848
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 4 steps took 2.06 seconds
# Epoch: 2 batch_num: 82 val_rmse: 0.4804
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 4 steps took 2.06 seconds
# Epoch: 2 batch_num: 86 val_rmse: 0.4775
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 88 val_rmse: 0.4777
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 90 val_rmse: 0.4809
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 4 steps took 2.05 seconds
# Epoch: 2 batch_num: 94 val_rmse: 0.483
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 4 steps took 2.05 seconds
# Epoch: 2 batch_num: 98 val_rmse: 0.479
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 100 val_rmse: 0.4771
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.1 seconds
# Epoch: 2 batch_num: 102 val_rmse: 0.4753
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 104 val_rmse: 0.4741
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 106 val_rmse: 0.4732
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 108 val_rmse: 0.4729
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 110 val_rmse: 0.4729
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 112 val_rmse: 0.473
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 114 val_rmse: 0.473
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 116 val_rmse: 0.4731
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 118 val_rmse: 0.4732
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 120 val_rmse: 0.4734
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 122 val_rmse: 0.4737
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 124 val_rmse: 0.4742
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 126 val_rmse: 0.4746
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 128 val_rmse: 0.4747
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 130 val_rmse: 0.475
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 132 val_rmse: 0.4752
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 134 val_rmse: 0.4754
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.04 seconds
# Epoch: 2 batch_num: 136 val_rmse: 0.4754
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.05 seconds
# Epoch: 2 batch_num: 138 val_rmse: 0.4755
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.04 seconds
# Epoch: 2 batch_num: 140 val_rmse: 0.4755
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 142 val_rmse: 0.4755
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 144 val_rmse: 0.4755
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.02 seconds
# Epoch: 2 batch_num: 146 val_rmse: 0.4755
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 148 val_rmse: 0.4755
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# 2 steps took 1.05 seconds
# Epoch: 2 batch_num: 150 val_rmse: 0.4755
# Still best_val_rmse: 0.4729 (from epoch 2)
#
# Performance estimates:
# [0.49190338384630194, 0.4481513582344671, 0.46446157179868375, 0.47284795280892244, 0.5004512219628822, 0.4728619115812866]
# Mean: 0.4751129000387573
#
# Fold 7/7
# Some weights of RobertaModel were not initialized from the model checkpoint at ../input/clrp-roberta-base/clrp_roberta_base and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 16 steps took 8.87 seconds
# Epoch: 0 batch_num: 16 val_rmse: 0.9503
# New best_val_rmse: 0.9503
#
# 16 steps took 8.23 seconds
# Epoch: 0 batch_num: 32 val_rmse: 0.7445
# New best_val_rmse: 0.7445
#
# 16 steps took 8.17 seconds
# Epoch: 0 batch_num: 48 val_rmse: 0.7168
# New best_val_rmse: 0.7168
#
# 16 steps took 8.2 seconds
# Epoch: 0 batch_num: 64 val_rmse: 0.6742
# New best_val_rmse: 0.6742
#
# 16 steps took 8.27 seconds
# Epoch: 0 batch_num: 80 val_rmse: 0.6242
# New best_val_rmse: 0.6242
#
# 16 steps took 8.23 seconds
# Epoch: 0 batch_num: 96 val_rmse: 0.5893
# New best_val_rmse: 0.5893
#
# 16 steps took 8.24 seconds
# Epoch: 0 batch_num: 112 val_rmse: 0.6304
# Still best_val_rmse: 0.5893 (from epoch 0)
#
# 16 steps took 8.19 seconds
# Epoch: 0 batch_num: 128 val_rmse: 0.6059
# Still best_val_rmse: 0.5893 (from epoch 0)
#
# 16 steps took 8.19 seconds
# Epoch: 0 batch_num: 144 val_rmse: 0.5472
# New best_val_rmse: 0.5472
#
# 16 steps took 8.45 seconds
# Epoch: 1 batch_num: 9 val_rmse: 0.6582
# Still best_val_rmse: 0.5472 (from epoch 0)
#
# 16 steps took 8.19 seconds
# Epoch: 1 batch_num: 25 val_rmse: 0.5719
# Still best_val_rmse: 0.5472 (from epoch 0)
#
# 16 steps took 8.21 seconds
# Epoch: 1 batch_num: 41 val_rmse: 0.5253
# New best_val_rmse: 0.5253
#
# 16 steps took 8.21 seconds
# Epoch: 1 batch_num: 57 val_rmse: 0.5107
# New best_val_rmse: 0.5107
#
# 16 steps took 8.27 seconds
# Epoch: 1 batch_num: 73 val_rmse: 0.558
# Still best_val_rmse: 0.5107 (from epoch 1)
#
# 16 steps took 8.3 seconds
# Epoch: 1 batch_num: 89 val_rmse: 0.5945
# Still best_val_rmse: 0.5107 (from epoch 1)
#
# 16 steps took 8.2 seconds
# Epoch: 1 batch_num: 105 val_rmse: 0.5461
# Still best_val_rmse: 0.5107 (from epoch 1)
#
# 16 steps took 8.26 seconds
# Epoch: 1 batch_num: 121 val_rmse: 0.5153
# Still best_val_rmse: 0.5107 (from epoch 1)
#
# 16 steps took 8.21 seconds
# Epoch: 1 batch_num: 137 val_rmse: 0.5442
# Still best_val_rmse: 0.5107 (from epoch 1)
#
# 16 steps took 8.35 seconds
# Epoch: 2 batch_num: 2 val_rmse: 0.5126
# Still best_val_rmse: 0.5107 (from epoch 1)
#
# 16 steps took 8.23 seconds
# Epoch: 2 batch_num: 18 val_rmse: 0.5566
# Still best_val_rmse: 0.5107 (from epoch 1)
#
# 16 steps took 8.18 seconds
# Epoch: 2 batch_num: 34 val_rmse: 0.5275
# Still best_val_rmse: 0.5107 (from epoch 1)
#
# 16 steps took 8.27 seconds
# Epoch: 2 batch_num: 50 val_rmse: 0.5046
# New best_val_rmse: 0.5046
#
# 16 steps took 8.31 seconds
# Epoch: 2 batch_num: 66 val_rmse: 0.5071
# Still best_val_rmse: 0.5046 (from epoch 2)
#
# 16 steps took 8.18 seconds
# Epoch: 2 batch_num: 82 val_rmse: 0.5176
# Still best_val_rmse: 0.5046 (from epoch 2)
#
# 16 steps took 8.21 seconds
# Epoch: 2 batch_num: 98 val_rmse: 0.5056
# Still best_val_rmse: 0.5046 (from epoch 2)
#
# 16 steps took 8.19 seconds
# Epoch: 2 batch_num: 114 val_rmse: 0.5108
# Still best_val_rmse: 0.5046 (from epoch 2)
#
# 16 steps took 8.19 seconds
# Epoch: 2 batch_num: 130 val_rmse: 0.513
# Still best_val_rmse: 0.5046 (from epoch 2)
#
# 16 steps took 8.29 seconds
# Epoch: 2 batch_num: 146 val_rmse: 0.5122
# Still best_val_rmse: 0.5046 (from epoch 2)
#
# Performance estimates:
# [0.49190338384630194, 0.4481513582344671, 0.46446157179868375, 0.47284795280892244, 0.5004512219628822, 0.4728619115812866, 0.5046493459782094]
# Mean: 0.47933239231582186

# %% [markdown]
# # Inference

# %%
test_dataset = LitDataset(test_df, inference_only=True)

# %%
all_predictions = np.zeros((len(list_val_rmse), len(test_df)))

test_dataset = LitDataset(test_df, inference_only=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE,
                         drop_last=False, shuffle=False, num_workers=2)

for index in range(len(list_val_rmse)):            
    model_path = f"model_{index + 1}.pth"
    print(f"\nUsing {model_path}")
                        
    model = LitModel()
    model.load_state_dict(torch.load(model_path))    
    model.to(DEVICE)
    
    all_predictions[index] = predict(model, test_loader)
    
    del model
    gc.collect()
# Out:
# Using model_1.pth
# Some weights of RobertaModel were not initialized from the model checkpoint at ../input/clrp-roberta-base/clrp_roberta_base and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Using model_2.pth
# Some weights of RobertaModel were not initialized from the model checkpoint at ../input/clrp-roberta-base/clrp_roberta_base and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Using model_3.pth
# Some weights of RobertaModel were not initialized from the model checkpoint at ../input/clrp-roberta-base/clrp_roberta_base and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Using model_4.pth
# Some weights of RobertaModel were not initialized from the model checkpoint at ../input/clrp-roberta-base/clrp_roberta_base and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Using model_5.pth
# Some weights of RobertaModel were not initialized from the model checkpoint at ../input/clrp-roberta-base/clrp_roberta_base and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Using model_6.pth
# Some weights of RobertaModel were not initialized from the model checkpoint at ../input/clrp-roberta-base/clrp_roberta_base and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Using model_7.pth
# Some weights of RobertaModel were not initialized from the model checkpoint at ../input/clrp-roberta-base/clrp_roberta_base and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
predictions = all_predictions.mean(axis=0)
submission_df.target = predictions
print(submission_df)
submission_df.to_csv("submission.csv", index=False)
# Out:
#           id    target
# 0  c0f722661 -0.399351
# 1  f0953f0a5 -0.645916
# 2  0df072751 -0.399908
# 3  04caf4e0c -2.534776
# 4  0e63f8bea -1.638422
# 5  12537fe78 -1.449965
# 6  965e592c0  0.187443
